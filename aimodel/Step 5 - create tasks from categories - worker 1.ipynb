# %%
API_KEY = 'REDACTED'

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import google.generativeai as genai
from datetime import datetime
import csv
import re

# %% [markdown]
# # Prompt

# %%
def get_prompt(CATEGORY, SUBCATEGORY):
    return f"""
    CATEGORY
    {CATEGORY}
    
    SUBCATEGORY
    {SUBCATEGORY}
    
    COLUMNS
    Index, Category, Subcategory, Task,	App, Difficulty (1-10), Frequency (1-10)
    
    INSTRUCTION
    generate a table called TABLE, an exhaustive and comprehensive list of tasks that would be done on a computer in the given category: {CATEGORY} and subcategory: {SUBCATEGORY}
    
    each task needs to be specific - i need to be able to give this table to someone and get them to do screen recordings of themselves doing each task. 
    
    the tasks cannot be too complicated or vague or require additional information beyond the task description.
    
    Lean towards over-estimating the task difficulty. 

    The frequency should be estimating how often a computer user would need to do that task

    Do not give choice in the Task e.g. "Enable or disable the system mouse scroll wheel" is bad and should rather be something like "Enable and then disable the system mouse scroll wheel"
    
    make sure to create a new row in the table for each app / website that can be used to accomplish each task
    
    a reasonable average person should agree with the time and difficulty estimates.
    
    make the examples as specific as possible without revealing personal information. 

    do not use any ambiguity e.g. do not say "Various Forums" for the app, rather pick specific forums, for example.

    specify the platform / os if there is any ambiguity e.g. "Finder" -> "MacOS Finder"

    for broad subcategories like "Application Launch", do not return a row for every possible application but rather pick a few representative examples and make sure all platforms are covered

    start by reflecting on the apps / websites that a desktop computer user would use in the given category and subcategory then write all the tasks that can be completed so that the final TABLE contains all tasks across all apps/websites that apply to the category and subcategory

    be sure to make the table contain rows for all common apps / operating systems / websites in the given category/subcategory
    
    return nothing else but TABLE with "|" delimiters.
    """

# %% [markdown]
# # Setup Gemini

# %%
genai.configure(api_key=API_KEY)

generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
]

# %% [markdown]
# # Load Jobs

# %%
# Load the CSV file
file_path = 'categories.csv'
categories = pd.read_csv(file_path)

print(categories.head())
print("...")
print(categories.tail())
# Out:
#    Index           Category              Subcategory
# 0      1  Operating Systems          File Navigation
# 1      2  Operating Systems       Application Launch
# 2      3  Operating Systems          System Settings
# 3      4  Operating Systems          Task Management
# 4      5  Operating Systems  User Account Management
# ...
#      Index             Category                                  Subcategory
# 228    229   Security & Privacy                             Password Manager
# 229    230   Security & Privacy                              Data Encryption
# 230    231  Finance and Banking                        Cryptocurrency Basics
# 231    232  Finance and Banking  Cryptocurrency Decentralized (e.g. Uniswap)
# 232    233         Social Media                                        x.com

# %% [markdown]
# # Use gemini to get tasks for each job

# %%
for index, row in categories.iterrows():
    CATEGORY = row['Category']
    SUBCATEGORY = row['Subcategory']

    # output csv of tasks for this job
    FILENAME = f'TASKS/{index}_{CATEGORY}_{SUBCATEGORY}.csv'

    PROMPT = get_prompt(CATEGORY, SUBCATEGORY)

    #print(PROMPT)

    # skip if already done
    if os.path.exists(FILENAME):
        print(f"[loading saved data] {index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")
    else:
        print(f"{index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")

        try:
            model = None
            
            # get jobs CSV using gemini
            model = genai.GenerativeModel(
                model_name="gemini-1.5-flash",
                safety_settings=safety_settings,
                generation_config=generation_config,
            )
            
            start_time = datetime.now()
            print(f"Start time: {start_time}")
            
            chat_session = model.start_chat(
                history=[
                    {
                        "role": "user",
                        "parts": [
                            PROMPT,
                        ],
                    }
                ]
            )
            
            response = chat_session.send_message("Produce a TABLE as per the instructions above.")
            end_time = datetime.now()
            duration = end_time - start_time
            
            print(f"End time: {end_time}")
            print(f"Gemini API request duration: {duration}")
        
            # Remove extra newlines and split the response text into lines
            lines = response.text.strip().split('\n')[0:]
            
            # Extract the header and rows
            header = re.split(r'\s*\|\s*', lines[0].strip('|'))
            rows = [re.split(r'\s*\|\s*', line.strip('|')) for line in lines[1:]]
            
            # Write to CSV
            with open(FILENAME, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
        
            print("Saving file")
        except Exception as e:
            print(f"[ERROR] {index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")
            print(e)
# Out:
# [loading saved data] 1/233 CATEGORY: Operating Systems, SUBCATEGORY: File Navigation
# [loading saved data] 2/233 CATEGORY: Operating Systems, SUBCATEGORY: Application Launch
# [loading saved data] 3/233 CATEGORY: Operating Systems, SUBCATEGORY: System Settings
# [loading saved data] 4/233 CATEGORY: Operating Systems, SUBCATEGORY: Task Management
# [loading saved data] 5/233 CATEGORY: Operating Systems, SUBCATEGORY: User Account Management
# [loading saved data] 6/233 CATEGORY: Operating Systems, SUBCATEGORY: Security Settings
# [loading saved data] 7/233 CATEGORY: Operating Systems, SUBCATEGORY: Updates or Patches
# [loading saved data] 8/233 CATEGORY: Productivity Software, SUBCATEGORY: Document Creation
# [loading saved data] 9/233 CATEGORY: Productivity Software, SUBCATEGORY: Spreadsheet Manipulation
# [loading saved data] 10/233 CATEGORY: Productivity Software, SUBCATEGORY: Presentation Design
# [loading saved data] 11/233 CATEGORY: Productivity Software, SUBCATEGORY: Email Composition
# [loading saved data] 12/233 CATEGORY: Productivity Software, SUBCATEGORY: Calendar Management
# [loading saved data] 13/233 CATEGORY: Productivity Software, SUBCATEGORY: Task Management
# [loading saved data] 14/233 CATEGORY: Productivity Software, SUBCATEGORY: Project Management
# [loading saved data] 15/233 CATEGORY: Productivity Software, SUBCATEGORY: Note Taking
# [loading saved data] 16/233 CATEGORY: Productivity Software, SUBCATEGORY: Mind Mapping
# [loading saved data] 17/233 CATEGORY: Productivity Software, SUBCATEGORY: Workflow Automation
# [loading saved data] 18/233 CATEGORY: Web Browsers, SUBCATEGORY: Website Navigation
# [loading saved data] 19/233 CATEGORY: Web Browsers, SUBCATEGORY: Search Queries
# [loading saved data] 20/233 CATEGORY: Web Browsers, SUBCATEGORY: Tab Management
# [loading saved data] 21/233 CATEGORY: Web Browsers, SUBCATEGORY: Bookmarking
# [loading saved data] 22/233 CATEGORY: Web Browsers, SUBCATEGORY: History Management
# [loading saved data] 23/233 CATEGORY: Web Browsers, SUBCATEGORY: Extension Installation
# [loading saved data] 24/233 CATEGORY: Web Browsers, SUBCATEGORY: Privacy Settings
# [loading saved data] 25/233 CATEGORY: Communication Tools, SUBCATEGORY: Instant Messaging
# [loading saved data] 26/233 CATEGORY: Communication Tools, SUBCATEGORY: Video Calls
# [loading saved data] 27/233 CATEGORY: Communication Tools, SUBCATEGORY: Email Sending or Receiving
# [loading saved data] 28/233 CATEGORY: Communication Tools, SUBCATEGORY: Collaboration Tools
# [loading saved data] 29/233 CATEGORY: Communication Tools, SUBCATEGORY: File Sharing
# [loading saved data] 30/233 CATEGORY: Communication Tools, SUBCATEGORY: Voice Calls
# [loading saved data] 31/233 CATEGORY: Development Tools, SUBCATEGORY: Code Editing
# [loading saved data] 32/233 CATEGORY: Development Tools, SUBCATEGORY: Code Compilation
# [loading saved data] 33/233 CATEGORY: Development Tools, SUBCATEGORY: Debugging
# [loading saved data] 34/233 CATEGORY: Development Tools, SUBCATEGORY: Version Control
# [loading saved data] 35/233 CATEGORY: Development Tools, SUBCATEGORY: Database Management
# [loading saved data] 36/233 CATEGORY: Development Tools, SUBCATEGORY: Testing Frameworks
# [loading saved data] 37/233 CATEGORY: Development Tools, SUBCATEGORY: API Integration
# [loading saved data] 38/233 CATEGORY: Design and Creativity, SUBCATEGORY: Graphic Design
# [loading saved data] 39/233 CATEGORY: Design and Creativity, SUBCATEGORY: Video Editing
# [loading saved data] 40/233 CATEGORY: Design and Creativity, SUBCATEGORY: 3D Modeling
# [loading saved data] 41/233 CATEGORY: Design and Creativity, SUBCATEGORY: Digital Painting
# [loading saved data] 42/233 CATEGORY: Design and Creativity, SUBCATEGORY: Animation
# [loading saved data] 43/233 CATEGORY: Design and Creativity, SUBCATEGORY: Web Design
# [loading saved data] 44/233 CATEGORY: Design and Creativity, SUBCATEGORY: UI or UX Design
# [loading saved data] 45/233 CATEGORY: Design and Creativity, SUBCATEGORY: Photography Editing
# [loading saved data] 46/233 CATEGORY: Design and Creativity, SUBCATEGORY: Audio Editing
# [loading saved data] 47/233 CATEGORY: Security Software, SUBCATEGORY: Password Management
# [loading saved data] 48/233 CATEGORY: Security Software, SUBCATEGORY: Antivirus Installation
# [loading saved data] 49/233 CATEGORY: Security Software, SUBCATEGORY: Firewall Configuration
# [loading saved data] 50/233 CATEGORY: Security Software, SUBCATEGORY: VPN Connection
# [loading saved data] 51/233 CATEGORY: Security Software, SUBCATEGORY: Privacy Settings
# [loading saved data] 52/233 CATEGORY: Security Software, SUBCATEGORY: Data Encryption
# [loading saved data] 53/233 CATEGORY: File Management, SUBCATEGORY: File Copying
# [loading saved data] 54/233 CATEGORY: File Management, SUBCATEGORY: File Moving
# [loading saved data] 55/233 CATEGORY: File Management, SUBCATEGORY: File Deleting
# [loading saved data] 56/233 CATEGORY: File Management, SUBCATEGORY: File Renaming
# [loading saved data] 57/233 CATEGORY: File Management, SUBCATEGORY: File Compression or Extraction
# [loading saved data] 58/233 CATEGORY: File Management, SUBCATEGORY: File Sharing
# [loading saved data] 59/233 CATEGORY: File Management, SUBCATEGORY: Folder Organization
# [loading saved data] 60/233 CATEGORY: File Management, SUBCATEGORY: Data Backup
# [loading saved data] 61/233 CATEGORY: File Management, SUBCATEGORY: Disk Management
# [loading saved data] 62/233 CATEGORY: Entertainment Software, SUBCATEGORY: Music Playback
# [loading saved data] 63/233 CATEGORY: Entertainment Software, SUBCATEGORY: Video Streaming
# [loading saved data] 64/233 CATEGORY: Entertainment Software, SUBCATEGORY: Game Playing
# [loading saved data] 65/233 CATEGORY: Entertainment Software, SUBCATEGORY: Digital Content Consumption
# [loading saved data] 66/233 CATEGORY: Entertainment Software, SUBCATEGORY: Streaming Services Management
# [loading saved data] 67/233 CATEGORY: Entertainment Software, SUBCATEGORY: Digital Media Library Organization
# [loading saved data] 68/233 CATEGORY: Utilities, SUBCATEGORY: System Cleaning
# [loading saved data] 69/233 CATEGORY: Utilities, SUBCATEGORY: Disk Management
# [loading saved data] 70/233 CATEGORY: Utilities, SUBCATEGORY: Clipboard Management
# [loading saved data] 71/233 CATEGORY: Utilities, SUBCATEGORY: File Conversion
# [loading saved data] 72/233 CATEGORY: Utilities, SUBCATEGORY: System Optimization
# [loading saved data] 73/233 CATEGORY: Utilities, SUBCATEGORY: Screen Capture
# [loading saved data] 74/233 CATEGORY: Utilities, SUBCATEGORY: System Monitoring
# [loading saved data] 75/233 CATEGORY: Search Engines, SUBCATEGORY: Keyword Searching
# [loading saved data] 76/233 CATEGORY: Search Engines, SUBCATEGORY: Result Filtering
# [loading saved data] 77/233 CATEGORY: Search Engines, SUBCATEGORY: Website Exploration
# [loading saved data] 78/233 CATEGORY: Search Engines, SUBCATEGORY: Advanced Search Operators
# [loading saved data] 79/233 CATEGORY: Search Engines, SUBCATEGORY: Image Search
# [loading saved data] 80/233 CATEGORY: Search Engines, SUBCATEGORY: Voice Search
# [loading saved data] 81/233 CATEGORY: Social Media, SUBCATEGORY: Profile Management
# [loading saved data] 82/233 CATEGORY: Social Media, SUBCATEGORY: Post Creation
# [loading saved data] 83/233 CATEGORY: Social Media, SUBCATEGORY: Content Consumption
# [loading saved data] 84/233 CATEGORY: Social Media, SUBCATEGORY: Messaging
# [loading saved data] 85/233 CATEGORY: Social Media, SUBCATEGORY: Community Engagement
# [loading saved data] 86/233 CATEGORY: Social Media, SUBCATEGORY: Social Media Advertising
# [loading saved data] 87/233 CATEGORY: E-commerce, SUBCATEGORY: Product Search
# [loading saved data] 88/233 CATEGORY: E-commerce, SUBCATEGORY: Shopping Cart Management
# [loading saved data] 89/233 CATEGORY: E-commerce, SUBCATEGORY: Order Placement
# [loading saved data] 90/233 CATEGORY: E-commerce, SUBCATEGORY: Payment Processing
# [loading saved data] 91/233 CATEGORY: E-commerce, SUBCATEGORY: Account Management
# [loading saved data] 92/233 CATEGORY: E-commerce, SUBCATEGORY: Reviews
# [loading saved data] 93/233 CATEGORY: E-commerce, SUBCATEGORY: Wishlist Creation
# [loading saved data] 94/233 CATEGORY: News and Information, SUBCATEGORY: Article Reading
# [loading saved data] 95/233 CATEGORY: News and Information, SUBCATEGORY: Content Exploration
# [loading saved data] 96/233 CATEGORY: News and Information, SUBCATEGORY: News Subscription
# [loading saved data] 97/233 CATEGORY: News and Information, SUBCATEGORY: RSS Feed Management
# [loading saved data] 98/233 CATEGORY: News and Information, SUBCATEGORY: News Aggregation
# [loading saved data] 99/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Course Enrollment
# [loading saved data] 100/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Lesson Completion
# [loading saved data] 101/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Quiz Taking
# [loading saved data] 102/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Online Discussion
# [loading saved data] 103/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Certificate Management
# [loading saved data] 104/233 CATEGORY: Education and E-Learning, SUBCATEGORY: Learning Platform Navigation
# [loading saved data] 105/233 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Project Management
# [loading saved data] 106/233 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Task Management
# [loading saved data] 107/233 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Scheduling
# [loading saved data] 108/233 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Document Collaboration
# [loading saved data] 109/233 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Team Communication
# [loading saved data] 110/233 CATEGORY: Finance and Banking, SUBCATEGORY: Account Access
# [loading saved data] 111/233 CATEGORY: Finance and Banking, SUBCATEGORY: Transaction Management
# [loading saved data] 112/233 CATEGORY: Finance and Banking, SUBCATEGORY: Bill Payment
# [loading saved data] 113/233 CATEGORY: Finance and Banking, SUBCATEGORY: Investment Management
# [loading saved data] 114/233 CATEGORY: Finance and Banking, SUBCATEGORY: Budgeting Tools
# [loading saved data] 115/233 CATEGORY: Finance and Banking, SUBCATEGORY: Financial Planning
# [loading saved data] 116/233 CATEGORY: Finance and Banking, SUBCATEGORY: Tax Filing Software
# [loading saved data] 117/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Flight or Hotel Booking
# [loading saved data] 118/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Itinerary Planning
# [loading saved data] 119/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Travel Information
# [loading saved data] 120/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Destination Research
# [loading saved data] 121/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Booking Management
# [loading saved data] 122/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Travel Insurance
# [loading saved data] 123/233 CATEGORY: Travel and Hospitality, SUBCATEGORY: Transportation Booking
# [loading saved data] 124/233 CATEGORY: Health & Fitness, SUBCATEGORY: Health Data Tracking
# [loading saved data] 125/233 CATEGORY: Health & Fitness, SUBCATEGORY: Fitness Tracking
# [loading saved data] 126/233 CATEGORY: Health & Fitness, SUBCATEGORY: Workout Guidance
# [loading saved data] 127/233 CATEGORY: Health & Fitness, SUBCATEGORY: Nutrition Information
# [loading saved data] 128/233 CATEGORY: Health & Fitness, SUBCATEGORY: Health Management
# [loading saved data] 129/233 CATEGORY: Development & Design, SUBCATEGORY: Code Repository Navigation
# [loading saved data] 130/233 CATEGORY: Development & Design, SUBCATEGORY: Documentation Reading
# [loading saved data] 131/233 CATEGORY: Development & Design, SUBCATEGORY: Community Interaction
# [loading saved data] 132/233 CATEGORY: Development & Design, SUBCATEGORY: Design Inspiration
# [loading saved data] 133/233 CATEGORY: Development & Design, SUBCATEGORY: Design Collaboration Tools
# [loading saved data] 134/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Job Application
# [loading saved data] 135/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Profile Creation
# [loading saved data] 136/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Company Research
# [loading saved data] 137/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Job Board Navigation
# [loading saved data] 138/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Resume Optimization
# [loading saved data] 139/233 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Interview Preparation
# [loading saved data] 140/233 CATEGORY: Forums & Communities, SUBCATEGORY: Topic Exploration
# [loading saved data] 141/233 CATEGORY: Forums & Communities, SUBCATEGORY: Question Answering
# [loading saved data] 142/233 CATEGORY: Forums & Communities, SUBCATEGORY: Discussion Participation
# [loading saved data] 143/233 CATEGORY: Forums & Communities, SUBCATEGORY: Community Moderation
# [loading saved data] 144/233 CATEGORY: Forums & Communities, SUBCATEGORY: Forum Navigation
# [loading saved data] 145/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Information Retrieval
# [loading saved data] 146/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Article Reading
# [loading saved data] 147/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Fact Checking
# [loading saved data] 148/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Wikipedia Navigation
# [loading saved data] 149/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Online Encyclopedia Use
# [loading saved data] 150/233 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Dictionary and Thesaurus Use
# [loading saved data] 151/233 CATEGORY: Cloud Storage, SUBCATEGORY: File Upload or Download
# [loading saved data] 152/233 CATEGORY: Cloud Storage, SUBCATEGORY: Folder Management
# [loading saved data] 153/233 CATEGORY: Cloud Storage, SUBCATEGORY: Sharing Files
# [loading saved data] 154/233 CATEGORY: Cloud Storage, SUBCATEGORY: Synchronization
# [loading saved data] 155/233 CATEGORY: Cloud Storage, SUBCATEGORY: Data Backup
# [loading saved data] 156/233 CATEGORY: Cloud Storage, SUBCATEGORY: Version History Management
# [loading saved data] 157/233 CATEGORY: Mobile Apps, SUBCATEGORY: Application Launch
# [loading saved data] 158/233 CATEGORY: Mobile Apps, SUBCATEGORY: Task Completion
# [loading saved data] 159/233 CATEGORY: Mobile Apps, SUBCATEGORY: Interaction with Interface
# [loading saved data] 160/233 CATEGORY: Mobile Apps, SUBCATEGORY: App Store Navigation
# [loading saved data] 161/233 CATEGORY: Mobile Apps, SUBCATEGORY: App Settings
# [loading saved data] 162/233 CATEGORY: Mobile Apps, SUBCATEGORY: Permissions Management
# [loading saved data] 163/233 CATEGORY: Business Software, SUBCATEGORY: CRM Management
# [loading saved data] 164/233 CATEGORY: Business Software, SUBCATEGORY: Project Management
# [loading saved data] 165/233 CATEGORY: Business Software, SUBCATEGORY: Data Analysis
# [loading saved data] 166/233 CATEGORY: Business Software, SUBCATEGORY: Accounting Software
# [loading saved data] 167/233 CATEGORY: Business Software, SUBCATEGORY: Customer Support Software
# [loading saved data] 168/233 CATEGORY: Photography & Imaging, SUBCATEGORY: Photo Editing
# [loading saved data] 169/233 CATEGORY: Photography & Imaging, SUBCATEGORY: Image Enhancement
# [loading saved data] 170/233 CATEGORY: Photography & Imaging, SUBCATEGORY: Photo Sharing
# [loading saved data] 171/233 CATEGORY: Photography & Imaging, SUBCATEGORY: Raw Processing
# [loading saved data] 172/233 CATEGORY: Photography & Imaging, SUBCATEGORY: Digital Asset Management
# [loading saved data] 173/233 CATEGORY: Audio Software, SUBCATEGORY: Audio Editing
# [loading saved data] 174/233 CATEGORY: Audio Software, SUBCATEGORY: Music Production
# [loading saved data] 175/233 CATEGORY: Audio Software, SUBCATEGORY: Sound Design
# [loading saved data] 176/233 CATEGORY: Audio Software, SUBCATEGORY: Audio Mixing and Mastering
# [loading saved data] 177/233 CATEGORY: Audio Software, SUBCATEGORY: Podcast Production
# [loading saved data] 178/233 CATEGORY: Scientific & Research, SUBCATEGORY: Data Analysis
# [loading saved data] 179/233 CATEGORY: Scientific & Research, SUBCATEGORY: Simulation
# [loading saved data] 180/233 CATEGORY: Scientific & Research, SUBCATEGORY: Visualization
# [loading saved data] 181/233 CATEGORY: Scientific & Research, SUBCATEGORY: Scientific Software
# [loading saved data] 182/233 CATEGORY: Scientific & Research, SUBCATEGORY: Research Databases
# [loading saved data] 183/233 CATEGORY: Language Learning, SUBCATEGORY: Language Course Engagement
# [loading saved data] 184/233 CATEGORY: Language Learning, SUBCATEGORY: Vocabulary Building
# [loading saved data] 185/233 CATEGORY: Language Learning, SUBCATEGORY: Translation Use
# [loading saved data] 186/233 CATEGORY: Language Learning, SUBCATEGORY: Language Learning Apps
# [loading saved data] 187/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Location Search
# [loading saved data] 188/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Route Planning
# [loading saved data] 189/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Navigation Assistance
# [loading saved data] 190/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Traffic Information
# [loading saved data] 191/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Street View
# [loading saved data] 192/233 CATEGORY: Maps & Navigation, SUBCATEGORY: Map Customization
# [loading saved data] 193/233 CATEGORY: Personal Finance, SUBCATEGORY: Budgeting
# [loading saved data] 194/233 CATEGORY: Personal Finance, SUBCATEGORY: Investing
# [loading saved data] 195/233 CATEGORY: Personal Finance, SUBCATEGORY: Bill Tracking
# [loading saved data] 196/233 CATEGORY: Personal Finance, SUBCATEGORY: Financial Planning
# [loading saved data] 197/233 CATEGORY: Personal Finance, SUBCATEGORY: Tax Filing Software
# [loading saved data] 198/233 CATEGORY: Shopping, SUBCATEGORY: Product Research
# [loading saved data] 199/233 CATEGORY: Shopping, SUBCATEGORY: Shopping Cart Management
# [loading saved data] 200/233 CATEGORY: Shopping, SUBCATEGORY: Purchase Completion
# [loading saved data] 201/233 CATEGORY: Shopping, SUBCATEGORY: Price Comparison
# [loading saved data] 202/233 CATEGORY: Shopping, SUBCATEGORY: Deal Finding
# [loading saved data] 203/233 CATEGORY: Shopping, SUBCATEGORY: Shopping App Navigation
# [loading saved data] 204/233 CATEGORY: Sports & Recreation, SUBCATEGORY: Sports News Consumption
# [loading saved data] 205/233 CATEGORY: Sports & Recreation, SUBCATEGORY: Game Live Streaming
# [loading saved data] 206/233 CATEGORY: Sports & Recreation, SUBCATEGORY: Fitness Tracking
# [loading saved data] 207/233 CATEGORY: Sports & Recreation, SUBCATEGORY: Sports Statistics
# [loading saved data] 208/233 CATEGORY: Sports & Recreation, SUBCATEGORY: Virtual Reality Gaming
# [loading saved data] 209/233 CATEGORY: Art & Design, SUBCATEGORY: Digital Painting
# [loading saved data] 210/233 CATEGORY: Art & Design, SUBCATEGORY: Illustration
# [loading saved data] 211/233 CATEGORY: Art & Design, SUBCATEGORY: Graphic Design
# [loading saved data] 212/233 CATEGORY: Art & Design, SUBCATEGORY: 3D Printing
# [loading saved data] 213/233 CATEGORY: Art & Design, SUBCATEGORY: Web Design
# [loading saved data] 214/233 CATEGORY: Gaming, SUBCATEGORY: Game Launch
# [loading saved data] 215/233 CATEGORY: Gaming, SUBCATEGORY: Gameplay
# [loading saved data] 216/233 CATEGORY: Gaming, SUBCATEGORY: Multiplayer Interaction
# [loading saved data] 217/233 CATEGORY: Gaming, SUBCATEGORY: Achievement Tracking
# [loading saved data] 218/233 CATEGORY: Gaming, SUBCATEGORY: Game Library Management
# [loading saved data] 219/233 CATEGORY: Gaming, SUBCATEGORY: Game Customization
# [loading saved data] 220/233 CATEGORY: Gaming, SUBCATEGORY: Streaming Platforms
# [loading saved data] 221/233 CATEGORY: Productivity & Time Management, SUBCATEGORY: Calendar Management
# [loading saved data] 222/233 CATEGORY: Productivity & Time Management, SUBCATEGORY: To-Do List Maintenance
# [loading saved data] 223/233 CATEGORY: Productivity & Time Management, SUBCATEGORY: Time Tracking
# [loading saved data] 224/233 CATEGORY: Productivity & Time Management, SUBCATEGORY: Focus Tools
# [loading saved data] 225/233 CATEGORY: Productivity & Time Management, SUBCATEGORY: Productivity Apps
# [loading saved data] 226/233 CATEGORY: Security & Privacy, SUBCATEGORY: VPN Connection
# [loading saved data] 227/233 CATEGORY: Security & Privacy, SUBCATEGORY: Privacy Setting Configuration
# [loading saved data] 228/233 CATEGORY: Security & Privacy, SUBCATEGORY: Malware Removal
# [loading saved data] 229/233 CATEGORY: Security & Privacy, SUBCATEGORY: Password Manager
# [loading saved data] 230/233 CATEGORY: Security & Privacy, SUBCATEGORY: Data Encryption
# [loading saved data] 231/233 CATEGORY: Finance and Banking, SUBCATEGORY: Cryptocurrency Basics
# [loading saved data] 232/233 CATEGORY: Finance and Banking, SUBCATEGORY: Cryptocurrency Decentralized (e.g. Uniswap)
# 233/233 CATEGORY: Social Media, SUBCATEGORY: x.com
# Start time: 2024-06-02 04:19:38.886228
# End time: 2024-06-02 04:20:37.360054
# Gemini API request duration: 0:00:58.473826
# Saving file
