# %%
API_KEY = 'REDACTED'

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import google.generativeai as genai
from datetime import datetime
import csv
import re

# %% [markdown]
# # Prompt

# %%
def get_prompt(CATEGORY, SUBCATEGORY):
    return f"""
    CATEGORY
    {CATEGORY}
    
    SUBCATEGORY
    {SUBCATEGORY}
    
    COLUMNS
    Index, Category, Subcategory, Task,	App, Difficulty (1-10), Frequency (1-10)
    
    INSTRUCTION
    generate a table called TABLE, an exhaustive and comprehensive list of tasks that would be done on a computer in the given category: {CATEGORY} and subcategory: {SUBCATEGORY}
    
    each task needs to be specific - i need to be able to give this table to someone and get them to do screen recordings of themselves doing each task. 
    
    the tasks cannot be too complicated or vague or require additional information beyond the task description.
    
    Lean towards over-estimating the task difficulty. 

    The frequency should be estimating how often a computer user would need to do that task

    Do not give choice in the Task e.g. "Enable or disable the system mouse scroll wheel" is bad and should rather be something like "Enable and then disable the system mouse scroll wheel"
    
    make sure to create a new row in the table for each app / website that can be used to accomplish each task
    
    a reasonable average person should agree with the time and difficulty estimates.
    
    make the examples as specific as possible without revealing personal information. 

    do not use any ambiguity e.g. do not say "Various Forums" for the app, rather pick specific forums, for example.

    specify the platform / os if there is any ambiguity e.g. "Finder" -> "MacOS Finder"

    for broad subcategories like "Application Launch", do not return a row for every possible application but rather pick a few representative examples and make sure all platforms are covered

    start by reflecting on the apps / websites that a desktop computer user would use in the given category and subcategory then write all the tasks that can be completed so that the final TABLE contains all tasks across all apps/websites that apply to the category and subcategory

    be sure to make the table contain rows for all common apps / operating systems / websites in the given category/subcategory
    
    return nothing else but TABLE with "|" delimiters.
    """

# %% [markdown]
# # Setup Gemini

# %%
genai.configure(api_key=API_KEY)

generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
]

# %% [markdown]
# # Load Jobs

# %%
# Load the CSV file
file_path = 'categories.csv'
categories = pd.read_csv(file_path)

print(categories.head())
print("...")
print(categories.tail())
# Out:
#    Index           Category              Subcategory
# 0      1  Operating Systems          File Navigation
# 1      2  Operating Systems       Application Launch
# 2      3  Operating Systems          System Settings
# 3      4  Operating Systems          Task Management
# 4      5  Operating Systems  User Account Management
# ...
#      Index             Category                                  Subcategory
# 227    228   Security & Privacy                              Malware Removal
# 228    229   Security & Privacy                             Password Manager
# 229    230   Security & Privacy                              Data Encryption
# 230    231  Finance and Banking                        Cryptocurrency Basics
# 231    232  Finance and Banking  Cryptocurrency Decentralized (e.g. Uniswap)

# %%
categories = categories.sort_values("Index", ascending=False)

# %% [markdown]
# # Use gemini to get tasks for each job

# %%
for index, row in categories.iterrows():
    CATEGORY = row['Category']
    SUBCATEGORY = row['Subcategory']

    # output csv of tasks for this job
    FILENAME = f'TASKS/{index}_{CATEGORY}_{SUBCATEGORY}.csv'

    PROMPT = get_prompt(CATEGORY, SUBCATEGORY)

    #print(PROMPT)

    # skip if already done
    if os.path.exists(FILENAME):
        print(f"[loading saved data] {index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")
    else:
        print(f"{index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")

        try:
            model = None
            
            # get jobs CSV using gemini
            model = genai.GenerativeModel(
                model_name="gemini-1.5-flash",
                safety_settings=safety_settings,
                generation_config=generation_config,
            )
            
            start_time = datetime.now()
            print(f"Start time: {start_time}")
            
            chat_session = model.start_chat(
                history=[
                    {
                        "role": "user",
                        "parts": [
                            PROMPT,
                        ],
                    }
                ]
            )
            
            response = chat_session.send_message("Produce a TABLE as per the instructions above.")
            end_time = datetime.now()
            duration = end_time - start_time
            
            print(f"End time: {end_time}")
            print(f"Gemini API request duration: {duration}")
        
            # Remove extra newlines and split the response text into lines
            lines = response.text.strip().split('\n')[0:]
            
            # Extract the header and rows
            header = re.split(r'\s*\|\s*', lines[0].strip('|'))
            rows = [re.split(r'\s*\|\s*', line.strip('|')) for line in lines[1:]]
            
            # Write to CSV
            with open(FILENAME, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
        
            print("Saving file")
        except Exception as e:
            print(f"[ERROR] {index+1}/{len(categories)} CATEGORY: {CATEGORY}, SUBCATEGORY: {SUBCATEGORY}")
            print(e)
# Out:
# 232/232 CATEGORY: Finance and Banking, SUBCATEGORY: Cryptocurrency Decentralized (e.g. Uniswap)
# Start time: 2024-06-02 02:30:47.621824
# End time: 2024-06-02 02:31:05.652452
# Gemini API request duration: 0:00:18.030628
# Saving file
# 231/232 CATEGORY: Finance and Banking, SUBCATEGORY: Cryptocurrency Basics
# Start time: 2024-06-02 02:31:05.663436
# End time: 2024-06-02 02:31:24.085953
# Gemini API request duration: 0:00:18.422517
# Saving file
# [loading saved data] 230/232 CATEGORY: Security & Privacy, SUBCATEGORY: Data Encryption
# [loading saved data] 229/232 CATEGORY: Security & Privacy, SUBCATEGORY: Password Manager
# [loading saved data] 228/232 CATEGORY: Security & Privacy, SUBCATEGORY: Malware Removal
# [loading saved data] 227/232 CATEGORY: Security & Privacy, SUBCATEGORY: Privacy Setting Configuration
# [loading saved data] 226/232 CATEGORY: Security & Privacy, SUBCATEGORY: VPN Connection
# [loading saved data] 225/232 CATEGORY: Productivity & Time Management, SUBCATEGORY: Productivity Apps
# [loading saved data] 224/232 CATEGORY: Productivity & Time Management, SUBCATEGORY: Focus Tools
# [loading saved data] 223/232 CATEGORY: Productivity & Time Management, SUBCATEGORY: Time Tracking
# [loading saved data] 222/232 CATEGORY: Productivity & Time Management, SUBCATEGORY: To-Do List Maintenance
# [loading saved data] 221/232 CATEGORY: Productivity & Time Management, SUBCATEGORY: Calendar Management
# [loading saved data] 220/232 CATEGORY: Gaming, SUBCATEGORY: Streaming Platforms
# [loading saved data] 219/232 CATEGORY: Gaming, SUBCATEGORY: Game Customization
# [loading saved data] 218/232 CATEGORY: Gaming, SUBCATEGORY: Game Library Management
# [loading saved data] 217/232 CATEGORY: Gaming, SUBCATEGORY: Achievement Tracking
# [loading saved data] 216/232 CATEGORY: Gaming, SUBCATEGORY: Multiplayer Interaction
# [loading saved data] 215/232 CATEGORY: Gaming, SUBCATEGORY: Gameplay
# [loading saved data] 214/232 CATEGORY: Gaming, SUBCATEGORY: Game Launch
# [loading saved data] 213/232 CATEGORY: Art & Design, SUBCATEGORY: Web Design
# 212/232 CATEGORY: Art & Design, SUBCATEGORY: 3D Printing
# Start time: 2024-06-02 02:31:24.095536
# End time: 2024-06-02 02:32:21.796138
# Gemini API request duration: 0:00:57.700602
# Saving file
# 211/232 CATEGORY: Art & Design, SUBCATEGORY: Graphic Design
# Start time: 2024-06-02 02:32:21.806872
# End time: 2024-06-02 02:33:21.181106
# Gemini API request duration: 0:00:59.374234
# Saving file
# 210/232 CATEGORY: Art & Design, SUBCATEGORY: Illustration
# Start time: 2024-06-02 02:33:21.204900
# End time: 2024-06-02 02:34:19.591253
# Gemini API request duration: 0:00:58.386353
# Saving file
# 209/232 CATEGORY: Art & Design, SUBCATEGORY: Digital Painting
# Start time: 2024-06-02 02:34:19.602970
# End time: 2024-06-02 02:35:18.181363
# Gemini API request duration: 0:00:58.578393
# Saving file
# 208/232 CATEGORY: Sports & Recreation, SUBCATEGORY: Virtual Reality Gaming
# Start time: 2024-06-02 02:35:18.189512
# End time: 2024-06-02 02:36:16.684983
# Gemini API request duration: 0:00:58.495471
# Saving file
# 207/232 CATEGORY: Sports & Recreation, SUBCATEGORY: Sports Statistics
# Start time: 2024-06-02 02:36:16.696237
# End time: 2024-06-02 02:37:13.963636
# Gemini API request duration: 0:00:57.267399
# Saving file
# 206/232 CATEGORY: Sports & Recreation, SUBCATEGORY: Fitness Tracking
# Start time: 2024-06-02 02:37:13.973522
# End time: 2024-06-02 02:38:11.980141
# Gemini API request duration: 0:00:58.006619
# Saving file
# 205/232 CATEGORY: Sports & Recreation, SUBCATEGORY: Game Live Streaming
# Start time: 2024-06-02 02:38:11.992286
# End time: 2024-06-02 02:39:09.194886
# Gemini API request duration: 0:00:57.202600
# Saving file
# 204/232 CATEGORY: Sports & Recreation, SUBCATEGORY: Sports News Consumption
# Start time: 2024-06-02 02:39:09.202497
# End time: 2024-06-02 02:39:25.468512
# Gemini API request duration: 0:00:16.266015
# Saving file
# 203/232 CATEGORY: Shopping, SUBCATEGORY: Shopping App Navigation
# Start time: 2024-06-02 02:39:25.472338
# End time: 2024-06-02 02:40:24.898532
# Gemini API request duration: 0:00:59.426194
# Saving file
# 202/232 CATEGORY: Shopping, SUBCATEGORY: Deal Finding
# Start time: 2024-06-02 02:40:24.906801
# End time: 2024-06-02 02:41:04.627157
# Gemini API request duration: 0:00:39.720356
# Saving file
# 201/232 CATEGORY: Shopping, SUBCATEGORY: Price Comparison
# Start time: 2024-06-02 02:41:04.633355
# End time: 2024-06-02 02:42:05.675666
# Gemini API request duration: 0:01:01.042311
# Saving file
# 200/232 CATEGORY: Shopping, SUBCATEGORY: Purchase Completion
# Start time: 2024-06-02 02:42:05.679925
# End time: 2024-06-02 02:43:07.025155
# Gemini API request duration: 0:01:01.345230
# Saving file
# 199/232 CATEGORY: Shopping, SUBCATEGORY: Shopping Cart Management
# Start time: 2024-06-02 02:43:07.034516
# End time: 2024-06-02 02:43:41.939881
# Gemini API request duration: 0:00:34.905365
# Saving file
# 198/232 CATEGORY: Shopping, SUBCATEGORY: Product Research
# Start time: 2024-06-02 02:43:41.950218
# End time: 2024-06-02 02:44:07.927503
# Gemini API request duration: 0:00:25.977285
# Saving file
# 197/232 CATEGORY: Personal Finance, SUBCATEGORY: Tax Filing Software
# Start time: 2024-06-02 02:44:07.930082
# End time: 2024-06-02 02:45:07.756251
# Gemini API request duration: 0:00:59.826169
# Saving file
# 196/232 CATEGORY: Personal Finance, SUBCATEGORY: Financial Planning
# Start time: 2024-06-02 02:45:07.764793
# End time: 2024-06-02 02:45:30.977509
# Gemini API request duration: 0:00:23.212716
# Saving file
# 195/232 CATEGORY: Personal Finance, SUBCATEGORY: Bill Tracking
# Start time: 2024-06-02 02:45:30.982554
# End time: 2024-06-02 02:46:06.509815
# Gemini API request duration: 0:00:35.527261
# Saving file
# 194/232 CATEGORY: Personal Finance, SUBCATEGORY: Investing
# Start time: 2024-06-02 02:46:06.517154
# End time: 2024-06-02 02:47:06.008682
# Gemini API request duration: 0:00:59.491528
# Saving file
# 193/232 CATEGORY: Personal Finance, SUBCATEGORY: Budgeting
# Start time: 2024-06-02 02:47:06.012472
# End time: 2024-06-02 02:47:54.105071
# Gemini API request duration: 0:00:48.092599
# Saving file
# 192/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Map Customization
# Start time: 2024-06-02 02:47:54.109274
# End time: 2024-06-02 02:48:55.838750
# Gemini API request duration: 0:01:01.729476
# Saving file
# 191/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Street View
# Start time: 2024-06-02 02:48:55.846563
# End time: 2024-06-02 02:49:12.353765
# Gemini API request duration: 0:00:16.507202
# Saving file
# 190/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Traffic Information
# Start time: 2024-06-02 02:49:12.359063
# End time: 2024-06-02 02:50:14.217388
# Gemini API request duration: 0:01:01.858325
# Saving file
# 189/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Navigation Assistance
# Start time: 2024-06-02 02:50:14.230315
# End time: 2024-06-02 02:51:07.191368
# Gemini API request duration: 0:00:52.961053
# Saving file
# 188/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Route Planning
# Start time: 2024-06-02 02:51:07.206036
# End time: 2024-06-02 02:52:08.992799
# Gemini API request duration: 0:01:01.786763
# Saving file
# 187/232 CATEGORY: Maps & Navigation, SUBCATEGORY: Location Search
# Start time: 2024-06-02 02:52:09.000653
# End time: 2024-06-02 02:52:40.175070
# Gemini API request duration: 0:00:31.174417
# Saving file
# 186/232 CATEGORY: Language Learning, SUBCATEGORY: Language Learning Apps
# Start time: 2024-06-02 02:52:40.184824
# End time: 2024-06-02 02:52:54.611119
# Gemini API request duration: 0:00:14.426295
# Saving file
# 185/232 CATEGORY: Language Learning, SUBCATEGORY: Translation Use
# Start time: 2024-06-02 02:52:54.614989
# End time: 2024-06-02 02:53:52.776176
# Gemini API request duration: 0:00:58.161187
# Saving file
# 184/232 CATEGORY: Language Learning, SUBCATEGORY: Vocabulary Building
# Start time: 2024-06-02 02:53:52.786656
# End time: 2024-06-02 02:54:50.096428
# Gemini API request duration: 0:00:57.309772
# Saving file
# 183/232 CATEGORY: Language Learning, SUBCATEGORY: Language Course Engagement
# Start time: 2024-06-02 02:54:50.108925
# End time: 2024-06-02 02:55:05.858283
# Gemini API request duration: 0:00:15.749358
# Saving file
# 182/232 CATEGORY: Scientific & Research, SUBCATEGORY: Research Databases
# Start time: 2024-06-02 02:55:05.861320
# End time: 2024-06-02 02:55:38.866080
# Gemini API request duration: 0:00:33.004760
# Saving file
# 181/232 CATEGORY: Scientific & Research, SUBCATEGORY: Scientific Software
# Start time: 2024-06-02 02:55:38.876631
# End time: 2024-06-02 02:56:36.822076
# Gemini API request duration: 0:00:57.945445
# Saving file
# 180/232 CATEGORY: Scientific & Research, SUBCATEGORY: Visualization
# Start time: 2024-06-02 02:56:36.832773
# End time: 2024-06-02 02:57:35.495807
# Gemini API request duration: 0:00:58.663034
# Saving file
# 179/232 CATEGORY: Scientific & Research, SUBCATEGORY: Simulation
# Start time: 2024-06-02 02:57:35.503908
# End time: 2024-06-02 02:57:44.102796
# Gemini API request duration: 0:00:08.598888
# Saving file
# 178/232 CATEGORY: Scientific & Research, SUBCATEGORY: Data Analysis
# Start time: 2024-06-02 02:57:44.111849
# End time: 2024-06-02 02:58:42.798700
# Gemini API request duration: 0:00:58.686851
# Saving file
# 177/232 CATEGORY: Audio Software, SUBCATEGORY: Podcast Production
# Start time: 2024-06-02 02:58:42.808544
# End time: 2024-06-02 02:59:10.288631
# Gemini API request duration: 0:00:27.480087
# Saving file
# 176/232 CATEGORY: Audio Software, SUBCATEGORY: Audio Mixing and Mastering
# Start time: 2024-06-02 02:59:10.293618
# End time: 2024-06-02 03:00:11.340797
# Gemini API request duration: 0:01:01.047179
# Saving file
# 175/232 CATEGORY: Audio Software, SUBCATEGORY: Sound Design
# Start time: 2024-06-02 03:00:11.351785
# End time: 2024-06-02 03:01:08.905008
# Gemini API request duration: 0:00:57.553223
# Saving file
# 174/232 CATEGORY: Audio Software, SUBCATEGORY: Music Production
# Start time: 2024-06-02 03:01:08.919439
# End time: 2024-06-02 03:02:09.688710
# Gemini API request duration: 0:01:00.769271
# Saving file
# 173/232 CATEGORY: Audio Software, SUBCATEGORY: Audio Editing
# Start time: 2024-06-02 03:02:09.698584
# End time: 2024-06-02 03:03:11.361377
# Gemini API request duration: 0:01:01.662793
# Saving file
# 172/232 CATEGORY: Photography & Imaging, SUBCATEGORY: Digital Asset Management
# Start time: 2024-06-02 03:03:11.372308
# End time: 2024-06-02 03:04:12.815772
# Gemini API request duration: 0:01:01.443464
# Saving file
# 171/232 CATEGORY: Photography & Imaging, SUBCATEGORY: Raw Processing
# Start time: 2024-06-02 03:04:12.824774
# End time: 2024-06-02 03:05:13.110328
# Gemini API request duration: 0:01:00.285554
# Saving file
# 170/232 CATEGORY: Photography & Imaging, SUBCATEGORY: Photo Sharing
# Start time: 2024-06-02 03:05:13.121296
# End time: 2024-06-02 03:05:37.570537
# Gemini API request duration: 0:00:24.449241
# Saving file
# 169/232 CATEGORY: Photography & Imaging, SUBCATEGORY: Image Enhancement
# Start time: 2024-06-02 03:05:37.575963
# End time: 2024-06-02 03:06:10.997598
# Gemini API request duration: 0:00:33.421635
# Saving file
# 168/232 CATEGORY: Photography & Imaging, SUBCATEGORY: Photo Editing
# Start time: 2024-06-02 03:06:11.007457
# End time: 2024-06-02 03:06:25.525961
# Gemini API request duration: 0:00:14.518504
# Saving file
# 167/232 CATEGORY: Business Software, SUBCATEGORY: Customer Support Software
# Start time: 2024-06-02 03:06:25.529186
# End time: 2024-06-02 03:07:24.858596
# Gemini API request duration: 0:00:59.329410
# Saving file
# 166/232 CATEGORY: Business Software, SUBCATEGORY: Accounting Software
# Start time: 2024-06-02 03:07:24.871756
# End time: 2024-06-02 03:07:49.011023
# Gemini API request duration: 0:00:24.139267
# Saving file
# 165/232 CATEGORY: Business Software, SUBCATEGORY: Data Analysis
# Start time: 2024-06-02 03:07:49.015600
# End time: 2024-06-02 03:08:50.912180
# Gemini API request duration: 0:01:01.896580
# Saving file
# 164/232 CATEGORY: Business Software, SUBCATEGORY: Project Management
# Start time: 2024-06-02 03:08:50.924291
# End time: 2024-06-02 03:09:54.002248
# Gemini API request duration: 0:01:03.077957
# Saving file
# 163/232 CATEGORY: Business Software, SUBCATEGORY: CRM Management
# Start time: 2024-06-02 03:09:54.013226
# End time: 2024-06-02 03:10:27.865408
# Gemini API request duration: 0:00:33.852182
# Saving file
# 162/232 CATEGORY: Mobile Apps, SUBCATEGORY: Permissions Management
# Start time: 2024-06-02 03:10:27.869432
# End time: 2024-06-02 03:11:30.050584
# Gemini API request duration: 0:01:02.181152
# Saving file
# 161/232 CATEGORY: Mobile Apps, SUBCATEGORY: App Settings
# Start time: 2024-06-02 03:11:30.060621
# End time: 2024-06-02 03:12:30.424127
# Gemini API request duration: 0:01:00.363506
# Saving file
# 160/232 CATEGORY: Mobile Apps, SUBCATEGORY: App Store Navigation
# Start time: 2024-06-02 03:12:30.436183
# End time: 2024-06-02 03:12:44.364744
# Gemini API request duration: 0:00:13.928561
# Saving file
# 159/232 CATEGORY: Mobile Apps, SUBCATEGORY: Interaction with Interface
# Start time: 2024-06-02 03:12:44.368279
# End time: 2024-06-02 03:13:42.886846
# Gemini API request duration: 0:00:58.518567
# Saving file
# 158/232 CATEGORY: Mobile Apps, SUBCATEGORY: Task Completion
# Start time: 2024-06-02 03:13:42.899516
# End time: 2024-06-02 03:14:00.042313
# Gemini API request duration: 0:00:17.142797
# Saving file
# 157/232 CATEGORY: Mobile Apps, SUBCATEGORY: Application Launch
# Start time: 2024-06-02 03:14:00.045427
# End time: 2024-06-02 03:15:01.112503
# Gemini API request duration: 0:01:01.067076
# Saving file
# 156/232 CATEGORY: Cloud Storage, SUBCATEGORY: Version History Management
# Start time: 2024-06-02 03:15:01.125030
# End time: 2024-06-02 03:16:02.773379
# Gemini API request duration: 0:01:01.648349
# Saving file
# 155/232 CATEGORY: Cloud Storage, SUBCATEGORY: Data Backup
# Start time: 2024-06-02 03:16:02.786196
# End time: 2024-06-02 03:17:04.774659
# Gemini API request duration: 0:01:01.988463
# Saving file
# 154/232 CATEGORY: Cloud Storage, SUBCATEGORY: Synchronization
# Start time: 2024-06-02 03:17:04.785675
# End time: 2024-06-02 03:18:09.283070
# Gemini API request duration: 0:01:04.497395
# Saving file
# 153/232 CATEGORY: Cloud Storage, SUBCATEGORY: Sharing Files
# Start time: 2024-06-02 03:18:09.295270
# End time: 2024-06-02 03:18:21.778080
# Gemini API request duration: 0:00:12.482810
# Saving file
# 152/232 CATEGORY: Cloud Storage, SUBCATEGORY: Folder Management
# Start time: 2024-06-02 03:18:21.788732
# End time: 2024-06-02 03:19:24.271591
# Gemini API request duration: 0:01:02.482859
# Saving file
# 151/232 CATEGORY: Cloud Storage, SUBCATEGORY: File Upload/Download
# Start time: 2024-06-02 03:19:24.285168
# End time: 2024-06-02 03:19:48.314295
# Gemini API request duration: 0:00:24.029127
# [ERROR] 151/232 CATEGORY: Cloud Storage, SUBCATEGORY: File Upload/Download
# [Errno 2] No such file or directory: 'TASKS/150_Cloud Storage_File Upload/Download.csv'
# 150/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Dictionary and Thesaurus Use
# Start time: 2024-06-02 03:19:48.317927
# End time: 2024-06-02 03:19:55.368940
# Gemini API request duration: 0:00:07.051013
# Saving file
# 149/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Online Encyclopedia Use
# Start time: 2024-06-02 03:19:55.371581
# End time: 2024-06-02 03:20:01.801318
# Gemini API request duration: 0:00:06.429737
# Saving file
# 148/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Wikipedia Navigation
# Start time: 2024-06-02 03:20:01.802641
# End time: 2024-06-02 03:21:01.224144
# Gemini API request duration: 0:00:59.421503
# Saving file
# 147/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Fact Checking
# Start time: 2024-06-02 03:21:01.234668
# End time: 2024-06-02 03:22:03.315618
# Gemini API request duration: 0:01:02.080950
# Saving file
# 146/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Article Reading
# Start time: 2024-06-02 03:22:03.324100
# End time: 2024-06-02 03:22:08.502910
# Gemini API request duration: 0:00:05.178810
# Saving file
# 145/232 CATEGORY: Reference & Knowledge Bases, SUBCATEGORY: Information Retrieval
# Start time: 2024-06-02 03:22:08.506285
# End time: 2024-06-02 03:22:46.846684
# Gemini API request duration: 0:00:38.340399
# Saving file
# 144/232 CATEGORY: Forums & Communities, SUBCATEGORY: Forum Navigation
# Start time: 2024-06-02 03:22:46.856756
# End time: 2024-06-02 03:23:50.034114
# Gemini API request duration: 0:01:03.177358
# Saving file
# 143/232 CATEGORY: Forums & Communities, SUBCATEGORY: Community Moderation
# Start time: 2024-06-02 03:23:50.043907
# End time: 2024-06-02 03:24:04.971136
# Gemini API request duration: 0:00:14.927229
# Saving file
# 142/232 CATEGORY: Forums & Communities, SUBCATEGORY: Discussion Participation
# Start time: 2024-06-02 03:24:04.977174
# End time: 2024-06-02 03:25:05.106298
# Gemini API request duration: 0:01:00.129124
# Saving file
# 141/232 CATEGORY: Forums & Communities, SUBCATEGORY: Question Answering
# Start time: 2024-06-02 03:25:05.116806
# End time: 2024-06-02 03:26:03.812753
# Gemini API request duration: 0:00:58.695947
# Saving file
# 140/232 CATEGORY: Forums & Communities, SUBCATEGORY: Topic Exploration
# Start time: 2024-06-02 03:26:03.832130
# End time: 2024-06-02 03:26:21.370923
# Gemini API request duration: 0:00:17.538793
# Saving file
# 139/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Interview Preparation
# Start time: 2024-06-02 03:26:21.373785
# End time: 2024-06-02 03:27:04.251439
# Gemini API request duration: 0:00:42.877654
# Saving file
# 138/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Resume Optimization
# Start time: 2024-06-02 03:27:04.263101
# End time: 2024-06-02 03:27:32.644495
# Gemini API request duration: 0:00:28.381394
# Saving file
# 137/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Job Board Navigation
# Start time: 2024-06-02 03:27:32.650204
# End time: 2024-06-02 03:28:03.832851
# Gemini API request duration: 0:00:31.182647
# Saving file
# 136/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Company Research
# Start time: 2024-06-02 03:28:03.836698
# End time: 2024-06-02 03:29:01.380397
# Gemini API request duration: 0:00:57.543699
# Saving file
# 135/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Profile Creation
# Start time: 2024-06-02 03:29:01.387529
# End time: 2024-06-02 03:30:00.413903
# Gemini API request duration: 0:00:59.026374
# Saving file
# 134/232 CATEGORY: Job Search & Recruitment, SUBCATEGORY: Job Application
# Start time: 2024-06-02 03:30:00.423899
# End time: 2024-06-02 03:30:58.529211
# Gemini API request duration: 0:00:58.105312
# Saving file
# 133/232 CATEGORY: Development & Design, SUBCATEGORY: Design Collaboration Tools
# Start time: 2024-06-02 03:30:58.540198
# End time: 2024-06-02 03:31:54.079822
# Gemini API request duration: 0:00:55.539624
# Saving file
# 132/232 CATEGORY: Development & Design, SUBCATEGORY: Design Inspiration
# Start time: 2024-06-02 03:31:54.087688
# End time: 2024-06-02 03:32:23.199961
# Gemini API request duration: 0:00:29.112273
# Saving file
# 131/232 CATEGORY: Development & Design, SUBCATEGORY: Community Interaction
# Start time: 2024-06-02 03:32:23.210823
# End time: 2024-06-02 03:33:00.878562
# Gemini API request duration: 0:00:37.667739
# Saving file
# 130/232 CATEGORY: Development & Design, SUBCATEGORY: Documentation Reading
# Start time: 2024-06-02 03:33:00.892368
# End time: 2024-06-02 03:33:27.976927
# Gemini API request duration: 0:00:27.084559
# Saving file
# 129/232 CATEGORY: Development & Design, SUBCATEGORY: Code Repository Navigation
# Start time: 2024-06-02 03:33:27.982623
# End time: 2024-06-02 03:34:26.629607
# Gemini API request duration: 0:00:58.646984
# Saving file
# 128/232 CATEGORY: Health & Fitness, SUBCATEGORY: Health Management
# Start time: 2024-06-02 03:34:26.640557
# End time: 2024-06-02 03:34:51.534956
# Gemini API request duration: 0:00:24.894399
# Saving file
# 127/232 CATEGORY: Health & Fitness, SUBCATEGORY: Nutrition Information
# Start time: 2024-06-02 03:34:51.540869
# End time: 2024-06-02 03:35:12.998003
# Gemini API request duration: 0:00:21.457134
# Saving file
# 126/232 CATEGORY: Health & Fitness, SUBCATEGORY: Workout Guidance
# Start time: 2024-06-02 03:35:13.002231
# End time: 2024-06-02 03:36:05.412204
# Gemini API request duration: 0:00:52.409973
# Saving file
# 125/232 CATEGORY: Health & Fitness, SUBCATEGORY: Fitness Tracking
# Start time: 2024-06-02 03:36:05.422004
# End time: 2024-06-02 03:36:54.491074
# Gemini API request duration: 0:00:49.069070
# Saving file
# 124/232 CATEGORY: Health & Fitness, SUBCATEGORY: Health Data Tracking
# Start time: 2024-06-02 03:36:54.500783
# End time: 2024-06-02 03:37:51.941849
# Gemini API request duration: 0:00:57.441066
# Saving file
# 123/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Transportation Booking
# Start time: 2024-06-02 03:37:51.946704
# End time: 2024-06-02 03:38:14.924703
# Gemini API request duration: 0:00:22.977999
# Saving file
# 122/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Travel Insurance
# Start time: 2024-06-02 03:38:14.931656
# End time: 2024-06-02 03:38:49.195589
# Gemini API request duration: 0:00:34.263933
# Saving file
# 121/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Booking Management
# Start time: 2024-06-02 03:38:49.218176
# End time: 2024-06-02 03:39:45.919862
# Gemini API request duration: 0:00:56.701686
# Saving file
# 120/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Destination Research
# Start time: 2024-06-02 03:39:45.931220
# End time: 2024-06-02 03:39:56.318933
# Gemini API request duration: 0:00:10.387713
# Saving file
# 119/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Travel Information
# Start time: 2024-06-02 03:39:56.321186
# End time: 2024-06-02 03:40:55.009736
# Gemini API request duration: 0:00:58.688550
# Saving file
# [loading saved data] 118/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Itinerary Planning
# 117/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Flight/Hotel Booking
# Start time: 2024-06-02 03:40:55.023837
# End time: 2024-06-02 03:41:55.190566
# Gemini API request duration: 0:01:00.166729
# [ERROR] 117/232 CATEGORY: Travel and Hospitality, SUBCATEGORY: Flight/Hotel Booking
# [Errno 2] No such file or directory: 'TASKS/116_Travel and Hospitality_Flight/Hotel Booking.csv'
# [loading saved data] 116/232 CATEGORY: Finance and Banking, SUBCATEGORY: Tax Filing Software
# [loading saved data] 115/232 CATEGORY: Finance and Banking, SUBCATEGORY: Financial Planning
# [loading saved data] 114/232 CATEGORY: Finance and Banking, SUBCATEGORY: Budgeting Tools
# [loading saved data] 113/232 CATEGORY: Finance and Banking, SUBCATEGORY: Investment Management
# [loading saved data] 112/232 CATEGORY: Finance and Banking, SUBCATEGORY: Bill Payment
# [loading saved data] 111/232 CATEGORY: Finance and Banking, SUBCATEGORY: Transaction Management
# [loading saved data] 110/232 CATEGORY: Finance and Banking, SUBCATEGORY: Account Access
# [loading saved data] 109/232 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Team Communication
# [loading saved data] 108/232 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Document Collaboration
# [loading saved data] 107/232 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Scheduling
# [loading saved data] 106/232 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Task Management
# [loading saved data] 105/232 CATEGORY: Productivity & Collaboration, SUBCATEGORY: Project Management
# [loading saved data] 104/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Learning Platform Navigation
# [loading saved data] 103/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Certificate Management
# [loading saved data] 102/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Online Discussion
# [loading saved data] 101/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Quiz Taking
# [loading saved data] 100/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Lesson Completion
# [loading saved data] 99/232 CATEGORY: Education and E-Learning, SUBCATEGORY: Course Enrollment
# [loading saved data] 98/232 CATEGORY: News and Information, SUBCATEGORY: News Aggregation
# [loading saved data] 97/232 CATEGORY: News and Information, SUBCATEGORY: RSS Feed Management
# [loading saved data] 96/232 CATEGORY: News and Information, SUBCATEGORY: News Subscription
# [loading saved data] 95/232 CATEGORY: News and Information, SUBCATEGORY: Content Exploration
# [loading saved data] 94/232 CATEGORY: News and Information, SUBCATEGORY: Article Reading
# [loading saved data] 93/232 CATEGORY: E-commerce, SUBCATEGORY: Wishlist Creation
# [loading saved data] 92/232 CATEGORY: E-commerce, SUBCATEGORY: Reviews
# [loading saved data] 91/232 CATEGORY: E-commerce, SUBCATEGORY: Account Management
# [loading saved data] 90/232 CATEGORY: E-commerce, SUBCATEGORY: Payment Processing
# [loading saved data] 89/232 CATEGORY: E-commerce, SUBCATEGORY: Order Placement
# [loading saved data] 88/232 CATEGORY: E-commerce, SUBCATEGORY: Shopping Cart Management
# [loading saved data] 87/232 CATEGORY: E-commerce, SUBCATEGORY: Product Search
# [loading saved data] 86/232 CATEGORY: Social Media, SUBCATEGORY: Social Media Advertising
# [loading saved data] 85/232 CATEGORY: Social Media, SUBCATEGORY: Community Engagement
# [loading saved data] 84/232 CATEGORY: Social Media, SUBCATEGORY: Messaging
# [loading saved data] 83/232 CATEGORY: Social Media, SUBCATEGORY: Content Consumption
# [loading saved data] 82/232 CATEGORY: Social Media, SUBCATEGORY: Post Creation
# [loading saved data] 81/232 CATEGORY: Social Media, SUBCATEGORY: Profile Management
# [loading saved data] 80/232 CATEGORY: Search Engines, SUBCATEGORY: Voice Search
# [loading saved data] 79/232 CATEGORY: Search Engines, SUBCATEGORY: Image Search
# [loading saved data] 78/232 CATEGORY: Search Engines, SUBCATEGORY: Advanced Search Operators
# [loading saved data] 77/232 CATEGORY: Search Engines, SUBCATEGORY: Website Exploration
# [loading saved data] 76/232 CATEGORY: Search Engines, SUBCATEGORY: Result Filtering
# [loading saved data] 75/232 CATEGORY: Search Engines, SUBCATEGORY: Keyword Searching
# [loading saved data] 74/232 CATEGORY: Utilities, SUBCATEGORY: System Monitoring
# [loading saved data] 73/232 CATEGORY: Utilities, SUBCATEGORY: Screen Capture
# [loading saved data] 72/232 CATEGORY: Utilities, SUBCATEGORY: System Optimization
# [loading saved data] 71/232 CATEGORY: Utilities, SUBCATEGORY: File Conversion
# [loading saved data] 70/232 CATEGORY: Utilities, SUBCATEGORY: Clipboard Management
# [loading saved data] 69/232 CATEGORY: Utilities, SUBCATEGORY: Disk Management
# [loading saved data] 68/232 CATEGORY: Utilities, SUBCATEGORY: System Cleaning
# [loading saved data] 67/232 CATEGORY: Entertainment Software, SUBCATEGORY: Digital Media Library Organization
# [loading saved data] 66/232 CATEGORY: Entertainment Software, SUBCATEGORY: Streaming Services Management
# [loading saved data] 65/232 CATEGORY: Entertainment Software, SUBCATEGORY: Digital Content Consumption
# [loading saved data] 64/232 CATEGORY: Entertainment Software, SUBCATEGORY: Game Playing
# [loading saved data] 63/232 CATEGORY: Entertainment Software, SUBCATEGORY: Video Streaming
# [loading saved data] 62/232 CATEGORY: Entertainment Software, SUBCATEGORY: Music Playback
# [loading saved data] 61/232 CATEGORY: File Management, SUBCATEGORY: Disk Management
# [loading saved data] 60/232 CATEGORY: File Management, SUBCATEGORY: Data Backup
# [loading saved data] 59/232 CATEGORY: File Management, SUBCATEGORY: Folder Organization
# [loading saved data] 58/232 CATEGORY: File Management, SUBCATEGORY: File Sharing
# 57/232 CATEGORY: File Management, SUBCATEGORY: File Compression/Extraction
# Start time: 2024-06-02 03:41:55.204089
# End time: 2024-06-02 03:42:39.606970
# Gemini API request duration: 0:00:44.402881
# [ERROR] 57/232 CATEGORY: File Management, SUBCATEGORY: File Compression/Extraction
# [Errno 2] No such file or directory: 'TASKS/56_File Management_File Compression/Extraction.csv'
# [loading saved data] 56/232 CATEGORY: File Management, SUBCATEGORY: File Renaming
# [loading saved data] 55/232 CATEGORY: File Management, SUBCATEGORY: File Deleting
# [loading saved data] 54/232 CATEGORY: File Management, SUBCATEGORY: File Moving
# [loading saved data] 53/232 CATEGORY: File Management, SUBCATEGORY: File Copying
# [loading saved data] 52/232 CATEGORY: Security Software, SUBCATEGORY: Data Encryption
# [loading saved data] 51/232 CATEGORY: Security Software, SUBCATEGORY: Privacy Settings
# [loading saved data] 50/232 CATEGORY: Security Software, SUBCATEGORY: VPN Connection
# [loading saved data] 49/232 CATEGORY: Security Software, SUBCATEGORY: Firewall Configuration
# [loading saved data] 48/232 CATEGORY: Security Software, SUBCATEGORY: Antivirus Installation
# [loading saved data] 47/232 CATEGORY: Security Software, SUBCATEGORY: Password Management
# [loading saved data] 46/232 CATEGORY: Design and Creativity, SUBCATEGORY: Audio Editing
# [loading saved data] 45/232 CATEGORY: Design and Creativity, SUBCATEGORY: Photography Editing
# 44/232 CATEGORY: Design and Creativity, SUBCATEGORY: UI/UX Design
# Start time: 2024-06-02 03:42:39.613178
# End time: 2024-06-02 03:43:00.437229
# Gemini API request duration: 0:00:20.824051
# [ERROR] 44/232 CATEGORY: Design and Creativity, SUBCATEGORY: UI/UX Design
# [Errno 2] No such file or directory: 'TASKS/43_Design and Creativity_UI/UX Design.csv'
# [loading saved data] 43/232 CATEGORY: Design and Creativity, SUBCATEGORY: Web Design
# [loading saved data] 42/232 CATEGORY: Design and Creativity, SUBCATEGORY: Animation
# [loading saved data] 41/232 CATEGORY: Design and Creativity, SUBCATEGORY: Digital Painting
# [loading saved data] 40/232 CATEGORY: Design and Creativity, SUBCATEGORY: 3D Modeling
# [loading saved data] 39/232 CATEGORY: Design and Creativity, SUBCATEGORY: Video Editing
# [loading saved data] 38/232 CATEGORY: Design and Creativity, SUBCATEGORY: Graphic Design
# [loading saved data] 37/232 CATEGORY: Development Tools, SUBCATEGORY: API Integration
# [loading saved data] 36/232 CATEGORY: Development Tools, SUBCATEGORY: Testing Frameworks
# [loading saved data] 35/232 CATEGORY: Development Tools, SUBCATEGORY: Database Management
# [loading saved data] 34/232 CATEGORY: Development Tools, SUBCATEGORY: Version Control
# [loading saved data] 33/232 CATEGORY: Development Tools, SUBCATEGORY: Debugging
# [loading saved data] 32/232 CATEGORY: Development Tools, SUBCATEGORY: Code Compilation
# [loading saved data] 31/232 CATEGORY: Development Tools, SUBCATEGORY: Code Editing
# [loading saved data] 30/232 CATEGORY: Communication Tools, SUBCATEGORY: Voice Calls
# [loading saved data] 29/232 CATEGORY: Communication Tools, SUBCATEGORY: File Sharing
# [loading saved data] 28/232 CATEGORY: Communication Tools, SUBCATEGORY: Collaboration Tools
# 27/232 CATEGORY: Communication Tools, SUBCATEGORY: Email Sending/Receiving
# Start time: 2024-06-02 03:43:00.442038
# End time: 2024-06-02 03:43:58.228980
# Gemini API request duration: 0:00:57.786942
# [ERROR] 27/232 CATEGORY: Communication Tools, SUBCATEGORY: Email Sending/Receiving
# [Errno 2] No such file or directory: 'TASKS/26_Communication Tools_Email Sending/Receiving.csv'
# [loading saved data] 26/232 CATEGORY: Communication Tools, SUBCATEGORY: Video Calls
# [loading saved data] 25/232 CATEGORY: Communication Tools, SUBCATEGORY: Instant Messaging
# [loading saved data] 24/232 CATEGORY: Web Browsers, SUBCATEGORY: Privacy Settings
# [loading saved data] 23/232 CATEGORY: Web Browsers, SUBCATEGORY: Extension Installation
# [loading saved data] 22/232 CATEGORY: Web Browsers, SUBCATEGORY: History Management
# [loading saved data] 21/232 CATEGORY: Web Browsers, SUBCATEGORY: Bookmarking
# [loading saved data] 20/232 CATEGORY: Web Browsers, SUBCATEGORY: Tab Management
# [loading saved data] 19/232 CATEGORY: Web Browsers, SUBCATEGORY: Search Queries
# [loading saved data] 18/232 CATEGORY: Web Browsers, SUBCATEGORY: Website Navigation
# [loading saved data] 17/232 CATEGORY: Productivity Software, SUBCATEGORY: Workflow Automation
# [loading saved data] 16/232 CATEGORY: Productivity Software, SUBCATEGORY: Mind Mapping
# [loading saved data] 15/232 CATEGORY: Productivity Software, SUBCATEGORY: Note Taking
# [loading saved data] 14/232 CATEGORY: Productivity Software, SUBCATEGORY: Project Management
# [loading saved data] 13/232 CATEGORY: Productivity Software, SUBCATEGORY: Task Management
# [loading saved data] 12/232 CATEGORY: Productivity Software, SUBCATEGORY: Calendar Management
# [loading saved data] 11/232 CATEGORY: Productivity Software, SUBCATEGORY: Email Composition
# [loading saved data] 10/232 CATEGORY: Productivity Software, SUBCATEGORY: Presentation Design
# [loading saved data] 9/232 CATEGORY: Productivity Software, SUBCATEGORY: Spreadsheet Manipulation
# [loading saved data] 8/232 CATEGORY: Productivity Software, SUBCATEGORY: Document Creation
# 7/232 CATEGORY: Operating Systems, SUBCATEGORY: Updates/Patches
# Start time: 2024-06-02 03:43:58.238722
# End time: 2024-06-02 03:44:55.674909
# Gemini API request duration: 0:00:57.436187
# [ERROR] 7/232 CATEGORY: Operating Systems, SUBCATEGORY: Updates/Patches
# [Errno 2] No such file or directory: 'TASKS/6_Operating Systems_Updates/Patches.csv'
# [loading saved data] 6/232 CATEGORY: Operating Systems, SUBCATEGORY: Security Settings
# [loading saved data] 5/232 CATEGORY: Operating Systems, SUBCATEGORY: User Account Management
# [loading saved data] 4/232 CATEGORY: Operating Systems, SUBCATEGORY: Task Management
# [loading saved data] 3/232 CATEGORY: Operating Systems, SUBCATEGORY: System Settings
# [loading saved data] 2/232 CATEGORY: Operating Systems, SUBCATEGORY: Application Launch
# [loading saved data] 1/232 CATEGORY: Operating Systems, SUBCATEGORY: File Navigation
