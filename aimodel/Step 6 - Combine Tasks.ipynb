# %%
API_KEY = 'REDACTED'

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import google.generativeai as genai
from datetime import datetime
import csv
import re

# %% [markdown]
# # Load data from folder and combine into single CSV

# %%
import pandas as pd
import os

# Set the path to your folder
folder_path = "TASKS"

# Create an empty list to store DataFrames
dfs = []

# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    # Only process CSV files
    if filename.endswith(".csv"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        print(file_path)
        
        # Read the CSV into a DataFrame
        df = pd.read_csv(file_path, usecols=[0, 1, 2,3,4,5,6])
        df = df[df['Category'] != '---']
        df.columns = 'Index,Category,Subcategory,Task,App,Difficulty (1-10),Frequency (1-10)'.split(',')
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.drop_duplicates(inplace=True)
combined_df.to_csv("all_tasks.csv", index=False)

print("All CSV files combined into 'all_tasks.csv'")
# Out:
# TASKS/174_Audio Software_Sound Design.csv
# TASKS/160_Mobile Apps_App Settings.csv
# TASKS/43_Design and Creativity_UI or UX Design.csv
# TASKS/189_Maps & Navigation_Traffic Information.csv
# TASKS/48_Security Software_Firewall Configuration.csv
# TASKS/67_Utilities_System Cleaning.csv
# TASKS/135_Job Search & Recruitment_Company Research.csv
# TASKS/166_Business Software_Customer Support Software.csv
# TASKS/201_Shopping_Deal Finding.csv
# TASKS/63_Entertainment Software_Game Playing.csv
# TASKS/0_Operating Systems_File Navigation.csv
# TASKS/147_Reference & Knowledge Bases_Wikipedia Navigation.csv
# TASKS/56_File Management_File Compression or Extraction.csv
# TASKS/70_Utilities_File Conversion.csv
# TASKS/132_Development & Design_Design Collaboration Tools.csv
# TASKS/111_Finance and Banking_Bill Payment.csv
# TASKS/202_Shopping_Shopping App Navigation.csv
# TASKS/183_Language Learning_Vocabulary Building.csv
# TASKS/102_Education and E-Learning_Certificate Management.csv
# TASKS/40_Design and Creativity_Digital Painting.csv
# TASKS/89_E-commerce_Payment Processing.csv
# TASKS/222_Productivity & Time Management_Time Tracking.csv
# TASKS/155_Cloud Storage_Version History Management.csv
# TASKS/83_Social Media_Messaging.csv
# TASKS/109_Finance and Banking_Account Access.csv
# TASKS/13_Productivity Software_Project Management.csv
# TASKS/86_E-commerce_Product Search.csv
# TASKS/204_Sports & Recreation_Game Live Streaming.csv
# TASKS/58_File Management_Folder Organization.csv
# TASKS/124_Health & Fitness_Fitness Tracking.csv
# TASKS/33_Development Tools_Version Control.csv
# TASKS/82_Social Media_Content Consumption.csv
# TASKS/35_Development Tools_Testing Frameworks.csv
# TASKS/55_File Management_File Renaming.csv
# TASKS/227_Security & Privacy_Malware Removal.csv
# TASKS/2_Operating Systems_System Settings.csv
# TASKS/81_Social Media_Post Creation.csv
# TASKS/61_Entertainment Software_Music Playback.csv
# TASKS/62_Entertainment Software_Video Streaming.csv
# TASKS/4_Operating Systems_User Account Management.csv
# TASKS/156_Mobile Apps_Application Launch.csv
# TASKS/158_Mobile Apps_Interaction with Interface.csv
# TASKS/92_E-commerce_Wishlist Creation.csv
# TASKS/117_Travel and Hospitality_Itinerary Planning.csv
# TASKS/218_Gaming_Game Customization.csv
# TASKS/140_Forums & Communities_Question Answering.csv
# TASKS/34_Development Tools_Database Management.csv
# TASKS/96_News and Information_RSS Feed Management.csv
# TASKS/106_Productivity & Collaboration_Scheduling.csv
# TASKS/6_Operating Systems_Updates or Patches.csv
# TASKS/41_Design and Creativity_Animation.csv
# TASKS/50_Security Software_Privacy Settings.csv
# TASKS/12_Productivity Software_Task Management.csv
# TASKS/72_Utilities_Screen Capture.csv
# TASKS/164_Business Software_Data Analysis.csv
# TASKS/219_Gaming_Streaming Platforms.csv
# TASKS/78_Search Engines_Image Search.csv
# TASKS/192_Personal Finance_Budgeting.csv
# TASKS/157_Mobile Apps_Task Completion.csv
# TASKS/172_Audio Software_Audio Editing.csv
# TASKS/194_Personal Finance_Bill Tracking.csv
# TASKS/211_Art & Design_3D Printing.csv
# TASKS/212_Art & Design_Web Design.csv
# TASKS/184_Language Learning_Translation Use.csv
# TASKS/77_Search Engines_Advanced Search Operators.csv
# TASKS/122_Travel and Hospitality_Transportation Booking.csv
# TASKS/49_Security Software_VPN Connection.csv
# TASKS/173_Audio Software_Music Production.csv
# TASKS/26_Communication Tools_Email Sending or Receiving.csv
# TASKS/146_Reference & Knowledge Bases_Fact Checking.csv
# TASKS/231_Finance and Banking_Cryptocurrency Decentralized (e.g. Uniswap).csv
# TASKS/11_Productivity Software_Calendar Management.csv
# TASKS/60_File Management_Disk Management.csv
# TASKS/153_Cloud Storage_Synchronization.csv
# TASKS/98_Education and E-Learning_Course Enrollment.csv
# TASKS/90_E-commerce_Account Management.csv
# TASKS/128_Development & Design_Code Repository Navigation.csv
# TASKS/103_Education and E-Learning_Learning Platform Navigation.csv
# TASKS/170_Photography & Imaging_Raw Processing.csv
# TASKS/182_Language Learning_Language Course Engagement.csv
# TASKS/133_Job Search & Recruitment_Job Application.csv
# TASKS/198_Shopping_Shopping Cart Management.csv
# TASKS/52_File Management_File Copying.csv
# TASKS/144_Reference & Knowledge Bases_Information Retrieval.csv
# TASKS/185_Language Learning_Language Learning Apps.csv
# TASKS/7_Productivity Software_Document Creation.csv
# TASKS/209_Art & Design_Illustration.csv
# TASKS/31_Development Tools_Code Compilation.csv
# TASKS/115_Finance and Banking_Tax Filing Software.csv
# TASKS/168_Photography & Imaging_Image Enhancement.csv
# TASKS/110_Finance and Banking_Transaction Management.csv
# TASKS/142_Forums & Communities_Community Moderation.csv
# TASKS/203_Sports & Recreation_Sports News Consumption.csv
# TASKS/30_Development Tools_Code Editing.csv
# TASKS/27_Communication Tools_Collaboration Tools.csv
# TASKS/162_Business Software_CRM Management.csv
# TASKS/8_Productivity Software_Spreadsheet Manipulation.csv
# TASKS/193_Personal Finance_Investing.csv
# TASKS/217_Gaming_Game Library Management.csv
# TASKS/178_Scientific & Research_Simulation.csv
# TASKS/95_News and Information_News Subscription.csv
# TASKS/44_Design and Creativity_Photography Editing.csv
# TASKS/9_Productivity Software_Presentation Design.csv
# TASKS/171_Photography & Imaging_Digital Asset Management.csv
# TASKS/23_Web Browsers_Privacy Settings.csv
# TASKS/131_Development & Design_Design Inspiration.csv
# TASKS/186_Maps & Navigation_Location Search.csv
# TASKS/73_Utilities_System Monitoring.csv
# TASKS/188_Maps & Navigation_Navigation Assistance.csv
# TASKS/59_File Management_Data Backup.csv
# TASKS/175_Audio Software_Audio Mixing and Mastering.csv
# TASKS/230_Finance and Banking_Cryptocurrency Basics.csv
# TASKS/3_Operating Systems_Task Management.csv
# TASKS/165_Business Software_Accounting Software.csv
# TASKS/93_News and Information_Article Reading.csv
# TASKS/104_Productivity & Collaboration_Project Management.csv
# TASKS/143_Forums & Communities_Forum Navigation.csv
# TASKS/57_File Management_File Sharing.csv
# TASKS/126_Health & Fitness_Nutrition Information.csv
# TASKS/169_Photography & Imaging_Photo Sharing.csv
# TASKS/161_Mobile Apps_Permissions Management.csv
# TASKS/139_Forums & Communities_Topic Exploration.csv
# TASKS/195_Personal Finance_Financial Planning.csv
# TASKS/206_Sports & Recreation_Sports Statistics.csv
# TASKS/21_Web Browsers_History Management.csv
# TASKS/66_Entertainment Software_Digital Media Library Organization.csv
# TASKS/176_Audio Software_Podcast Production.csv
# TASKS/36_Development Tools_API Integration.csv
# TASKS/197_Shopping_Product Research.csv
# TASKS/47_Security Software_Antivirus Installation.csv
# TASKS/105_Productivity & Collaboration_Task Management.csv
# TASKS/46_Security Software_Password Management.csv
# TASKS/224_Productivity & Time Management_Productivity Apps.csv
# TASKS/76_Search Engines_Website Exploration.csv
# TASKS/163_Business Software_Project Management.csv
# TASKS/99_Education and E-Learning_Lesson Completion.csv
# TASKS/22_Web Browsers_Extension Installation.csv
# TASKS/114_Finance and Banking_Financial Planning.csv
# TASKS/215_Gaming_Multiplayer Interaction.csv
# TASKS/68_Utilities_Disk Management.csv
# TASKS/87_E-commerce_Shopping Cart Management.csv
# TASKS/149_Reference & Knowledge Bases_Dictionary and Thesaurus Use.csv
# TASKS/80_Social Media_Profile Management.csv
# TASKS/187_Maps & Navigation_Route Planning.csv
# TASKS/154_Cloud Storage_Data Backup.csv
# TASKS/228_Security & Privacy_Password Manager.csv
# TASKS/112_Finance and Banking_Investment Management.csv
# TASKS/1_Operating Systems_Application Launch.csv
# TASKS/223_Productivity & Time Management_Focus Tools.csv
# TASKS/54_File Management_File Deleting.csv
# TASKS/120_Travel and Hospitality_Booking Management.csv
# TASKS/199_Shopping_Purchase Completion.csv
# TASKS/88_E-commerce_Order Placement.csv
# TASKS/129_Development & Design_Documentation Reading.csv
# TASKS/28_Communication Tools_File Sharing.csv
# TASKS/205_Sports & Recreation_Fitness Tracking.csv
# TASKS/65_Entertainment Software_Streaming Services Management.csv
# TASKS/125_Health & Fitness_Workout Guidance.csv
# TASKS/181_Scientific & Research_Research Databases.csv
# TASKS/91_E-commerce_Reviews.csv
# TASKS/167_Photography & Imaging_Photo Editing.csv
# TASKS/127_Health & Fitness_Health Management.csv
# TASKS/101_Education and E-Learning_Online Discussion.csv
# TASKS/180_Scientific & Research_Scientific Software.csv
# TASKS/216_Gaming_Achievement Tracking.csv
# TASKS/17_Web Browsers_Website Navigation.csv
# TASKS/191_Maps & Navigation_Map Customization.csv
# TASKS/148_Reference & Knowledge Bases_Online Encyclopedia Use.csv
# TASKS/51_Security Software_Data Encryption.csv
# TASKS/145_Reference & Knowledge Bases_Article Reading.csv
# TASKS/119_Travel and Hospitality_Destination Research.csv
# TASKS/42_Design and Creativity_Web Design.csv
# TASKS/84_Social Media_Community Engagement.csv
# TASKS/10_Productivity Software_Email Composition.csv
# TASKS/116_Travel and Hospitality_Flight or Hotel Booking.csv
# TASKS/94_News and Information_Content Exploration.csv
# TASKS/213_Gaming_Game Launch.csv
# TASKS/121_Travel and Hospitality_Travel Insurance.csv
# TASKS/25_Communication Tools_Video Calls.csv
# TASKS/20_Web Browsers_Bookmarking.csv
# TASKS/53_File Management_File Moving.csv
# TASKS/136_Job Search & Recruitment_Job Board Navigation.csv
# TASKS/214_Gaming_Gameplay.csv
# TASKS/45_Design and Creativity_Audio Editing.csv
# TASKS/74_Search Engines_Keyword Searching.csv
# TASKS/71_Utilities_System Optimization.csv
# TASKS/141_Forums & Communities_Discussion Participation.csv
# TASKS/107_Productivity & Collaboration_Document Collaboration.csv
# TASKS/113_Finance and Banking_Budgeting Tools.csv
# TASKS/37_Design and Creativity_Graphic Design.csv
# TASKS/39_Design and Creativity_3D Modeling.csv
# TASKS/210_Art & Design_Graphic Design.csv
# TASKS/16_Productivity Software_Workflow Automation.csv
# TASKS/69_Utilities_Clipboard Management.csv
# TASKS/207_Sports & Recreation_Virtual Reality Gaming.csv
# TASKS/137_Job Search & Recruitment_Resume Optimization.csv
# TASKS/100_Education and E-Learning_Quiz Taking.csv
# TASKS/32_Development Tools_Debugging.csv
# TASKS/196_Personal Finance_Tax Filing Software.csv
# TASKS/5_Operating Systems_Security Settings.csv
# TASKS/79_Search Engines_Voice Search.csv
# TASKS/159_Mobile Apps_App Store Navigation.csv
# TASKS/152_Cloud Storage_Sharing Files.csv
# TASKS/208_Art & Design_Digital Painting.csv
# TASKS/19_Web Browsers_Tab Management.csv
# TASKS/24_Communication Tools_Instant Messaging.csv
# TASKS/220_Productivity & Time Management_Calendar Management.csv
# TASKS/200_Shopping_Price Comparison.csv
# TASKS/130_Development & Design_Community Interaction.csv
# TASKS/108_Productivity & Collaboration_Team Communication.csv
# TASKS/64_Entertainment Software_Digital Content Consumption.csv
# TASKS/123_Health & Fitness_Health Data Tracking.csv
# TASKS/97_News and Information_News Aggregation.csv
# TASKS/29_Communication Tools_Voice Calls.csv
# TASKS/229_Security & Privacy_Data Encryption.csv
# TASKS/75_Search Engines_Result Filtering.csv
# TASKS/150_Cloud Storage_File Upload or Download.csv
# TASKS/138_Job Search & Recruitment_Interview Preparation.csv
# TASKS/179_Scientific & Research_Visualization.csv
# TASKS/226_Security & Privacy_Privacy Setting Configuration.csv
# TASKS/14_Productivity Software_Note Taking.csv
# TASKS/15_Productivity Software_Mind Mapping.csv
# TASKS/18_Web Browsers_Search Queries.csv
# TASKS/225_Security & Privacy_VPN Connection.csv
# TASKS/118_Travel and Hospitality_Travel Information.csv
# TASKS/38_Design and Creativity_Video Editing.csv
# TASKS/177_Scientific & Research_Data Analysis.csv
# TASKS/151_Cloud Storage_Folder Management.csv
# TASKS/134_Job Search & Recruitment_Profile Creation.csv
# TASKS/85_Social Media_Social Media Advertising.csv
# TASKS/221_Productivity & Time Management_To-Do List Maintenance.csv
# TASKS/190_Maps & Navigation_Street View.csv
# All CSV files combined into 'all_tasks.csv'

# %% [markdown]
# # Prompt

# %%
def get_prompt(JOB, CATEGORY):
    return f"""
    JOB
    {JOB}
    
    CATEGORY
    {CATEGORY}
    
    TABLE
    Index	Category	Task	App(s)	Example	App Count	Time Estimate (seconds)	Difficulty (1-10)
    1	Administration	Add a new contact to your phone	Contacts, Google Contacts, iCloud Contacts	Add a new contact named "John Smith" to your phone's contacts, including his phone number and email.	3	30	2
    2	Administration	Create a reminder in your calendar	Google Calendar, Outlook Calendar, Apple Calendar	Set a reminder for yourself to call your mom at 6:00 PM tonight.	3	20	1
    3	Administration	Create a to-do list in a task manager	Google Tasks, Todoist, TickTick, Microsoft To Do	Add a task to your to-do list: "Buy groceries for the week."	4	15	1
    4	Administration	Set up a recurring appointment in your calendar	Google Calendar, Outlook Calendar, Apple Calendar	Schedule a weekly yoga class on Tuesdays at 6:00 PM.	3	30	2
    5	Administration	Change your password for a website	Account settings of any website	Change your password for your online banking account, making sure it's strong and unique.	1	45	3
    6	Communication	Send a quick text message	Messages, WhatsApp, Telegram, Facebook Messenger	Send a quick message to your friend: "Hey, are you free tonight?"	4	10	1
    7	Communication	Send a quick email	Gmail, Outlook, Yahoo Mail, Apple Mail	Send a quick email to your friend inviting them to grab coffee tomorrow.	4	20	2
    8	Communication	Share a photo	Instagram, Facebook, WhatsApp, Telegram	Share a picture of your lunch on your Instagram story.	4	15	1
    9	Communication	Send a voice message	Voicemail, WhatsApp Voice Messages, Telegram Voice Messages	Leave a voice message for your friend letting them know you'll be late.	3	30	2
    10	Communication	Join a group chat	WhatsApp, Telegram, Facebook Messenger, Slack	Join a group chat invitation to coordinate the next family gathering.	4	10	1
    11	Communication	Update your profile picture	Facebook, Instagram, Twitter, LinkedIn	Change your profile picture on Facebook to a new photo of you.	4	20	2
    12	Creative Work	Create a simple drawing	Adobe Photoshop, Autodesk Sketchbook, Procreate	Draw a quick doodle in Adobe Photoshop using a simple brush.	3	45	3
    13	Creative Work	Edit a photo	Adobe Photoshop, GIMP, Snapseed, VSCO	Adjust the brightness and contrast of a photo in Snapseed.	4	20	2
    14	Creative Work	Create a simple graphic	Canva, Adobe Illustrator, Figma, Affinity Designer	Create a quick social media post graphic in Canva using a template.	4	30	2
    15	Creative Work	Add text to a photo	Adobe Photoshop, GIMP	Add a text overlay to a photo using Adobe Photoshop.	2	30	3
    16	Creative Work	Edit a video clip	Adobe Premiere Pro, Final Cut Pro, DaVinci Resolve	Trim the beginning and end of a video clip to remove unwanted parts.	3	45	4
    17	Customer Service	Ask a question on a company's website live chat	Intercom, LiveChat, Drift, Tawk.to, Olark	Ask a question about shipping times for your recent order using the company's live chat.	5	30	2
    18	Data Management	Enter data into a spreadsheet	Google Sheets, Microsoft Excel	Input your grocery expenses for the week into a spreadsheet.	2	45	3
    19	Data Management	Create a simple chart	Google Sheets, Microsoft Excel	Create a pie chart in Google Sheets to show your monthly budget allocation.	2	30	3
    20	Development	Run a code snippet	Jupyter Notebook, Google Colab	Run a basic Python code snippet to print "Hello, World!"	2	15	2
    21	Development	Edit a code file	Visual Studio Code, Atom	Correct a simple error in a Python code file using Visual Studio Code.	2	60	4
    22	Development	Save changes to a code file	Visual Studio Code, Atom	Save changes to a code file in Visual Studio Code after making a correction.	2	5	1
    23	Entertainment	Listen to a song	Spotify, Apple Music, YouTube Music	Play your favorite song on Spotify.	3	10	1
    24	Entertainment	Watch a short video	YouTube, Vimeo	Watch a short video on YouTube about a trending topic.	2	30	1
    25	Entertainment	Play a mobile game	Android Play Store, Apple App Store	Play a quick round of a mobile game on your phone.	2	10	1
    26	Finance	Check your bank account balance	Online banking app for your bank	Check your account balance using your bank's online banking app.	1	15	1
    27	Finance	Track an expense	Mint, YNAB, Personal Capital, EveryDollar, PocketGuard	Log a recent purchase of coffee using your budgeting app.	5	10	1
    28	Finance	Transfer money between accounts	Online banking app for your bank	Transfer $10 from your checking account to your savings account.	1	20	2
    29	Health and Fitness	Track a workout	Strava, MyFitnessPal, Fitbit, Apple Health	Log a 20-minute run in your fitness app, including distance and time.	4	30	2
    30	Health and Fitness	Check your sleep data	Fitbit, Apple Health	Check your sleep time and quality data using your Fitbit.	2	15	1
    31	Health and Fitness	Log your food intake	MyFitnessPal, Lose It, Cronometer	Log your breakfast today in your nutrition tracking app: "Oatmeal with fruit."	3	15	2
    32	Learning	Start a lesson	Duolingo, Babbel, Khan Academy	Start a lesson in Duolingo to learn Spanish.	3	20	2
    33	Learning	Watch a YouTube tutorial	YouTube	Watch a short YouTube tutorial on a new cooking technique.	1	30	1
    34	Learning	Search for a book	Amazon, Barnes & Noble, Google Books	Search for a book on a specific topic on Amazon and add it to your cart.	3	20	2
    35	Marketing	Schedule a social media post	Hootsuite, Buffer, SproutSocial, Later, TweetDeck	Schedule a post on your Instagram account to share a photo with a caption.	5	30	3
    36	Marketing	Create a simple infographic	Canva	Create a simple infographic in Canva to visually represent a statistic related to your business.	1	60	4
    37	Marketing	Check your website analytics	Google Analytics	Check the number of visitors to your website today using Google Analytics.	1	15	1
    38	Marketing	Reply to a comment on your social media post	Facebook, Instagram, Twitter	Reply to a comment on your latest tweet, thanking the commenter.	3	10	1
    39	Media Editing	Trim an audio recording	Audacity, GarageBand, Adobe Audition	Trim the beginning and end of a voice recording to remove silence.	3	30	3
    40	Media Editing	Convert an image to a different format	GIMP, ImageMagick, XnConvert, FreeImage, IrfanView	Convert a JPG image to a PNG format.	5	20	2
    41	Media Editing	Adjust the brightness of a photo	Adobe Photoshop, GIMP, Snapseed, VSCO	Adjust the brightness of a photo to make it more appealing.	4	15	2
    42	Media Editing	Add a simple transition effect to a video	Adobe Premiere Pro, Final Cut Pro, DaVinci Resolve	Add a simple fade-in transition effect to a video clip.	3	45	4
    43	Shopping	Add an item to your shopping cart	Amazon, eBay, Etsy	Add a new pair of shoes to your Amazon shopping cart.	3	10	1
    44	Shopping	Read product reviews	Amazon, eBay, Etsy	Read product reviews for a new laptop you're considering buying on Amazon.	3	60	3
    45	System Settings	Check your computer's storage space	Storage settings in OS	Check how much storage space is available on your computer.	1	10	1
    46	System Settings	Adjust your screen brightness	Display settings in OS	Adjust your computer's screen brightness to a comfortable level.	1	5	1
    47	Travel and Booking	Search for a flight	Expedia, Kayak, Skyscanner, Google Flights, Hopper	Search for a flight from New York to Los Angeles on Expedia.	5	30	2
    48	Travel and Booking	Check hotel prices	Booking.com, Airbnb, Expedia, Hotels.com	Check the prices for a hotel in Paris for your upcoming trip.	4	30	2
    49	Travel and Booking	Look up driving directions	Google Maps, Apple Maps, Waze	Look up driving directions from your current location to the grocery store.	3	15	1
    50	Crypto	Check your crypto wallet balance	MetaMask, Coinbase Wallet, Trust Wallet	Check the balance of your cryptocurrency portfolio in your MetaMask wallet.	3	15	2
    51	Crypto	Track the price of a cryptocurrency	CoinMarketCap, CoinGecko, TradingView	Track the current price of Bitcoin on CoinMarketCap.	3	10	1
    52	Home Automation	Turn on your smart lights	Google Home, Alexa, HomeKit	Turn on the lights in your living room using the Google Home app.	3	5	1
    53	Home Automation	Adjust your thermostat	Google Home, Alexa, HomeKit	Increase your thermostat by 2 degrees using the Alexa app.	3	10	1
    54	Home Automation	Play music	Google Home, Alexa, Sonos	Play your favorite song on your Google Home speaker.	3	10	1
    55	Food & Beverages	Order food delivery	Uber Eats, DoorDash, Grubhub	Order a salad from your favorite restaurant using the Uber Eats app.	3	20	2
    56	Food & Beverages	Search for a recipe	Allrecipes, Food Network, Epicurious	Find a quick and easy dinner recipe on Allrecipes.	3	20	2
    57	Social Media	Post a status update	Facebook, Instagram, Twitter, LinkedIn	Share a quick status update on Facebook about your day.	4	15	2
    58	Social Media	Like a friend's post	Facebook, Instagram, Twitter, LinkedIn	Like a friend's photo on Instagram.	4	5	1
    59	Social Media	Reply to a comment	Facebook, Instagram, Twitter, LinkedIn	Reply to a comment on your latest tweet, thanking the commenter.	4	10	1
    60	Education & Research	Look up the definition of a word	Merriam-Webster, Dictionary.com, Oxford Dictionaries	Look up the definition of the word "ubiquitous" on Merriam-Webster.	3	15	1
    61	Entertainment & Media	Watch a short YouTube video	YouTube, Vimeo	Watch a short video on YouTube about a funny cat.	2	20	1
    62	Personal Care	Book an appointment	Online booking systems for salons, doctors, etc.	Book a haircut appointment for next week at your favorite salon.	1	30	2
    63	Personal Care	Search for a local service	Yelp, Google Maps	Search for a local coffee shop on Yelp.	2	20	2
    64	Shopping & Retail	Add an item to your wishlist	Amazon, eBay, Etsy	Add a new book to your Amazon wishlist.	3	10	1
    65	Finance & Budgeting	Check your credit card balance	Online account for your credit card provider	Check the balance of your credit card online.	1	15	1
    66	Art Direction	Create a simple mockup using Canva	Canva	Create a simple mockup of a social media post using Canva.	1	45	3
    67	Art Direction	Find a free stock photo	Unsplash, Pixabay, Pexels	Find a free stock photo on Unsplash of a food item.	3	15	1
    68	Accounting	Record a single transaction in accounting software	Xero, QuickBooks, FreshBooks	Record a payment received from a client in Xero.	3	20	2
    69	Accounting	View a basic report	Xero, QuickBooks, FreshBooks	View a simple report in QuickBooks showing the current balance of your client's account.	3	15	1
    70	Acting	Search for an audition opportunity	Backstage, Actors Access	Search for an audition for a short film on Backstage.	2	30	2
    71	Acting	Read a movie script online	Script databases (e.g., IMSDb, Simply Scripts)	Read a short film script online.	2	45	3
    72	Architecture	Use a 3D modeling tool to create a simple model	SketchUp, Blender, Autodesk Revit	Create a simple 3D model of a chair in SketchUp.	3	60	4
    73	Architecture	Search for architectural styles	Pinterest, Houzz	Search for examples of Victorian architecture on Pinterest.	2	20	2
    74	Bioinformatics	View a protein sequence	UniProt	View the amino acid sequence of a specific protein in UniProt.	1	15	2
    75	Broadcast News	Use an audio editing tool to adjust volume	Audacity, Adobe Audition	Adjust the volume of an audio recording in Audacity.	2	30	3
    76	Broadcast News	Write a short social media post for news	Facebook, Twitter	Write a short social media post for a breaking news story.	2	20	2
    77	Chemical Science	Search for a chemical compound	PubChem	Search for the chemical compound "carbon dioxide" on PubChem.	1	15	2
    78	Civil Engineering	Use a CAD software to draw a simple shape	AutoCAD, Revit	Draw a circle using AutoCAD.	2	15	2
    79	Civil Engineering	View a construction site plan	AutoCAD, Revit	View a construction site plan for a new apartment building.	2	30	2
    80	Computer Science	Run a simple Python script	Visual Studio Code, Atom	Run a Python script to calculate the average of three numbers.	2	20	3
    81	Computer Science	Search for a programming language tutorial	Codecademy, W3Schools, FreeCodeCamp	Search for a beginner's Python tutorial on Codecademy.	3	20	2
    82	Computer Science	Open the Developer Console in a browser	Chrome DevTools, Firefox Developer Tools, Edge Developer Tools	Open the Developer Console in Chrome to view the code of a webpage.	3	5	1
    83	Dance	Watch a dance tutorial video on YouTube	YouTube	Watch a short dance tutorial for a specific move on YouTube.	1	30	1
    84	Dance	Share a dance video on TikTok	TikTok	Share a short dance video on your TikTok profile.	1	20	2
    85	Dance	Search for dance studios	Google Maps, Yelp	Search for dance studios in your city on Google Maps.	2	20	2
    86	Project Management	Create a new project in a project management tool	Trello, Asana, Jira	Create a new project in Trello to manage the launch of a new product.	3	30	2
    87	Project Management	Assign tasks to team members	Trello, Asana, Jira	Assign a specific task to a team member in Asana with a deadline.	3	15	1
    88	Project Management	Track project progress	Trello, Asana, Jira	View the progress of your project in Trello, including completed tasks and upcoming deadlines.	3	20	2
    89	Project Management	Collaborate on a project with team members	Trello, Asana, Jira	Discuss project updates and make changes to tasks in Asana with your team.	3	45	3
    90	Research & Information	Search for academic articles	Google Scholar, PubMed, JSTOR	Search for academic articles on the topic of climate change using Google Scholar.	3	30	2
    91	Research & Information	Read and analyze research papers	PDF readers (Adobe Acrobat Reader, etc.)	Read and analyze a research paper on a specific topic using Adobe Acrobat Reader.	1	60	4
    92	Research & Information	Create citations and bibliographies	Zotero, Mendeley, EndNote	Create a bibliography for a research paper using Zotero.	3	30	3
    93	Research & Information	Search for news articles	Google News, BBC News, CNN	Search for news articles about the latest political developments using Google News.	3	20	2
    94	Design & Graphics	Create a simple logo	Canva, Adobe Illustrator, Figma	Create a simple logo for your personal blog using Canva.	3	60	4
    95	Design & Graphics	Create a website mockup	Figma, Adobe XD, Sketch	Create a mockup of a website layout using Figma.	3	60	4
    96	Design & Graphics	Edit a vector graphic	Adobe Illustrator, Inkscape	Edit a vector graphic of a company logo in Adobe Illustrator.	2	45	3
    97	Design & Graphics	Create a simple infographic	Canva, Adobe Spark, Piktochart	Create a simple infographic to visualize data about your company's growth using Canva.	3	45	3
    98	Video Games	Play a video game	Steam, Epic Games Store, Origin	Play a game of "Fortnite" on your computer using Epic Games Store.	3	10	1
    99	Video Games	Stream gameplay	Twitch, YouTube Gaming	Stream your gameplay of "Minecraft" on Twitch.	2	30	2
    100	Video Games	Create a game mod	Modding tools for specific games	Create a new weapon mod for the game "Skyrim" using the Nexus Mod Manager.	1	120	6
    101	Programming	Write a simple Python script	Visual Studio Code, Atom	Write a Python script to check if a number is even or odd.	2	30	3
    102	Programming	Debug a code snippet	Visual Studio Code, Atom	Debug a Python script to find and fix an error in the code.	2	45	4
    103	Programming	Run unit tests	Python unittest, pytest	Run unit tests to ensure that a Python function is working correctly.	2	20	3
    104	Programming	Use a version control system	Git	Commit changes to a Python code project using Git and push them to a remote repository.	1	30	3
    105	Software Development	Design a user interface	Figma, Adobe XD, Sketch	Design the user interface for a new mobile app using Figma.	3	60	4
    106	Software Development	Develop a web application	HTML, CSS, JavaScript, Python (with frameworks like Django or Flask)	Develop a simple web application using HTML, CSS, and JavaScript to display a list of products.	4	120	6
    107	Software Development	Deploy a web application	Heroku, AWS, Google Cloud Platform	Deploy a simple web application to Heroku.	3	60	4
    108	Education & Training	Take an online course	Coursera, Udemy, edX	Enroll in a course on data science on Coursera and complete a lesson.	3	30	2
    109	Education & Training	Attend a webinar	Zoom, GoToWebinar	Attend a webinar on digital marketing and take notes.	2	60	3
    110	Education & Training	Create educational materials	PowerPoint, Google Slides, Prezi	Create a presentation for a training session on a new software tool.	3	60	4
    111	Data Analysis	Clean data in a spreadsheet	Google Sheets, Microsoft Excel	Clean up messy data in a spreadsheet by removing duplicates and fixing inconsistencies.	2	45	3
    112	Data Analysis	Create a visualization	Google Sheets, Microsoft Excel, Tableau	Create a bar chart in Google Sheets to visualize sales data for the last year.	3	30	3
    113	Data Analysis	Build a statistical model	Python (with libraries like scikit-learn)	Build a simple linear regression model in Python to predict sales based on marketing spend.	1	90	6
    114	Data Analysis	Analyze data using SQL	SQL databases (MySQL, PostgreSQL, etc.)	Use SQL to query a database and analyze sales data for a specific product.	1	30	3
    115	Security & Privacy	Manage passwords	Password managers (LastPass, 1Password, Dashlane)	Store and manage your passwords using LastPass.	3	20	2
    116	Security & Privacy	Use a VPN	NordVPN, ExpressVPN, CyberGhost	Connect to a VPN server to encrypt your internet traffic and protect your privacy.	3	15	2
    117	Security & Privacy	Scan your computer for malware	Antivirus software (Norton, McAfee, AVG)	Run a full system scan for malware using Norton Antivirus.	1	60	2
    118	Security & Privacy	Set up two-factor authentication	Two-factor authentication settings for accounts	Set up two-factor authentication for your Google account.	1	15	2
    119	Automation & Scripting	Automate a repetitive task	AutoHotkey, Keyboard Maestro, AppleScript	Create an AutoHotkey script to automate a repetitive task, such as sending emails.	1	60	4
    120	Automation & Scripting	Use a macro recorder	Macro recording software (AutoHotkey, Keyboard Maestro)	Record a series of actions in a macro recorder to automate a task.	1	30	3
    121	Automation & Scripting	Use a scripting language	Python, JavaScript, Bash	Write a simple Python script to download files from a website.	1	30	3
    122	Writing	Write a blog post	WordPress, Medium, Blogger	Write a blog post about a recent travel experience using WordPress.	3	60	3
    123	Writing	Write an email	Gmail, Outlook	Compose a professional email to a client.	2	30	2
    124	Writing	Write a letter	Microsoft Word, Google Docs	Write a formal letter to a government agency.	2	45	3
    125	Writing	Use a grammar checker	Grammarly, ProWritingAid, Hemingway Editor	Correct grammar and style errors in a document using Grammarly.	3	30	2
    126	Writing	Use a plagiarism checker	Plagiarism checkers (Grammarly, Turnitin, etc.)	Check a document for plagiarism using Grammarly.	1	15	1
    127	Web Development	Create a website using a website builder	Wix, Squarespace, WordPress	Create a simple website using Wix to showcase your portfolio.	3	60	3
    128	Web Development	Use HTML, CSS, and JavaScript	Text editors (Visual Studio Code, Atom), Web browsers (Chrome, Firefox)	Create a simple HTML webpage that displays a heading and paragraph.	3	30	2
    129	Web Development	Use a framework like React or Angular	JavaScript frameworks (React, Angular)	Build a dynamic web application using React to display a list of products.	2	120	6
    130	Web Development	Test a webpage	Browser developer tools, Selenium	Test a webpage using the developer tools in Chrome to ensure that it works correctly on different devices and browsers.	2	45	3
    131	Web Development	Deploy a website	Hosting providers (GoDaddy, Bluehost, HostGator), Cloud platforms (AWS, Google Cloud)	Deploy a website to GoDaddy using FTP.	2	45	3
    132	Photography	Edit photos in a photo editor	Adobe Photoshop, GIMP, Luminar	Edit a photo in Adobe Photoshop to adjust the colors, contrast, and brightness.	3	60	4
    133	Photography	Use a photo editing app	Snapseed, VSCO	Edit a photo in Snapseed to apply filters and make basic adjustments.	2	20	2
    134	Photography	Capture a photo	Camera software (Canon, Nikon, Sony)	Capture a photo using a DSLR camera and a specific lens.	1	30	2
    135	Photography	Share photos on social media	Facebook, Instagram, Twitter	Share a photo of your trip on Instagram.	3	15	1
    136	Video Editing	Create a video using a video editor	Adobe Premiere Pro, Final Cut Pro, DaVinci Resolve	Create a short video using Adobe Premiere Pro, including editing clips, adding transitions, and adding music.	3	120	6
    137	Video Editing	Use a video editing app	iMovie, KineMaster	Edit a short video clip in iMovie to add music and titles.	2	30	3
    138	Video Editing	Export a video in a specific format	Video editing software	Export a video in a format suitable for YouTube.	1	30	2
    139	Video Editing	Share a video on social media	YouTube, Facebook, Instagram	Upload a video of your trip to YouTube.	3	30	2
    140	Music	Create a song	Music production software (Ableton Live, FL Studio)	Create a simple song using Ableton Live, including adding instruments, recording vocals, and mixing.	1	120	6
    141	Music	Listen to music	Spotify, Apple Music, YouTube Music	Listen to your favorite playlist on Spotify.	3	10	1
    142	Music	Create a playlist	Spotify, Apple Music, YouTube Music	Create a playlist of your favorite songs on Spotify.	3	20	2
    143	Music	Share a song or playlist	Spotify, Apple Music, YouTube Music	Share a playlist of your favorite songs with a friend on Spotify.	3	10	1
    144	Animation	Create a simple animation	Adobe After Effects, Blender	Create a simple animation of a bouncing ball using Adobe After Effects.	2	60	4
    145	Animation	Use an animation software	Toon Boom Harmony, Adobe Animate	Create a simple animation of a character walking using Toon Boom Harmony.	2	60	4
    146	Animation	Export an animation in a specific format	Animation software	Export an animation in a format suitable for web playback.	1	30	2
    147	Animation	Share an animation online	YouTube, Vimeo, social media	Upload an animation to YouTube.	3	20	2
    148	Graphic Design	Create a simple flyer	Canva, Adobe InDesign	Design a simple flyer for an upcoming event using Canva.	2	45	3
    149	Graphic Design	Use a graphic design app	Canva, Adobe Spark	Create a simple graphic for a social media post using Canva.	2	30	2
    150	Graphic Design	Export a graphic in a specific format	Graphic design software	Export a flyer in a format suitable for printing.	1	20	2
    
    INSTRUCTION
    generate a table called NEW_TABLE, an exhaustive and comprehensive list of tasks that would be done on a computer for the given JOB={JOB} in a given work CATEGORY={CATEGORY}
    return NEW_TABLE in the same format as the sample TABLE
    make the examples specific - i need to be able to give this table to many people who work as a {JOB} and get them to do screen recordings of themselves doing the examples. it cannot be too complicated or vague.
    
    Here is a bad example - it's bad because it is asking too much of the user and is asking the user to do multiple things for the example and there's no way this could be done in 60 seconds: 
    31  Finance Use a pricing software  Specialized actuarial software  Actuarial Edge  Price a new insurance product using Actuarial Edge, considering factors like mortality rates, interest rates, and expenses. 1 60  4
    
    Here is a good example - it's good because it can be done quickly and is a single task and it's the right level of detail:
    57 Social Media Post a status update Facebook, Instagram, Twitter, LinkedIn Share a quick status update on Facebook about your day. 4 15 2
    
    lean towards over-estimating the time and difficulty. make the list of apps exhaustive and comprehensive for someone doing JOB on a computer. 
    
    a reasonable average person should agree with the time and difficulty estimates.
    
    make the examples as specific as possible without revealing personal information. 
    
    make your output contain only the required output NEW_TABLE giving examples of tasks done by people in the role of {JOB} ({CATEGORY}). 
    
    NEW_TABLE should have the following columns in order only: 
    Index,Category,Task,App(s),Example,App Count,Time Estimate (seconds),Difficulty (1-10)

    NEW_TABLE should only contain an exhaustive list of tasks done on a computer by a {JOB}.
    
    return nothing else but NEW_TABLE in the same format as TABLE with "|" delimiters.
    """

# %% [markdown]
# # Setup Gemini

# %%
genai.configure(api_key=API_KEY)

generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
]

# %% [markdown]
# # Load Jobs

# %%
# Load the CSV file
file_path = 'JOBS.csv'
jobs = pd.read_csv(file_path)

print(jobs.head())
print("...")
print(jobs.tail())
# Out:
#    Index                       Job                 Category
# 0      1           Account Manager    Business & Management
# 1      2                Accountant                  Finance
# 2      3                   Actuary                  Finance
# 3      4         Actuary Assistant                  Finance
# 4      5  Administrative Assistant  Office & Administration
# ...
#      Index                              Job         Category
# 495    496                        Counselor  Social Services
# 496    497               Counselor (Career)  Social Services
# 497    498    Counselor (Marriage & Family)  Social Services
# 498    499               Counselor (School)        Education
# 499    500  Customer Service Representative            Sales

# %% [markdown]
# # Use gemini to get tasks for each job

# %%
for index, row in jobs.iterrows():
    JOB = row['Job']
    CATEGORY = row['Category']

    # output csv of tasks for this job
    FILENAME = f'JOB_TASKS/{index}_{JOB}_{CATEGORY}.csv'

    PROMPT = get_prompt(JOB, CATEGORY)

    #print(PROMPT)

    # skip if already done
    if os.path.exists(FILENAME):
        print(f"[loading saved data] {index+1}/{len(jobs)} Job: {JOB}, Category: {CATEGORY}")
    else:
        print(f"{index+1}/{len(jobs)} Job: {JOB}, Category: {CATEGORY}")

        try:
            model = None
            
            # get jobs CSV using gemini
            model = genai.GenerativeModel(
                model_name="gemini-1.5-flash",
                safety_settings=safety_settings,
                generation_config=generation_config,
            )
            
            start_time = datetime.now()
            print(f"Start time: {start_time}")
            
            chat_session = model.start_chat(
                history=[
                    {
                        "role": "user",
                        "parts": [
                            PROMPT,
                        ],
                    }
                ]
            )
            
            response = chat_session.send_message("Produce NEW_TABLE as per the instructions above.")
            end_time = datetime.now()
            duration = end_time - start_time
            
            print(f"End time: {end_time}")
            print(f"Gemini API request duration: {duration}")
        
            # Remove extra newlines and split the response text into lines
            lines = response.text.strip().split('\n')[0:]
            
            # Extract the header and rows
            header = re.split(r'\s*\|\s*', lines[0].strip('|'))
            rows = [re.split(r'\s*\|\s*', line.strip('|')) for line in lines[1:]]
            
            # Write to CSV
            with open(FILENAME, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
        
            print("Saving file")
        except Exception as e:
            print(f"[ERROR] {index+1}/{len(jobs)} Job: {JOB}, Category: {CATEGORY}")
            print(e)
# Out:
# [loading saved data] 1/500 Job: Account Manager, Category: Business & Management
# [loading saved data] 2/500 Job: Accountant, Category: Finance
# [loading saved data] 3/500 Job: Actuary, Category: Finance
# [loading saved data] 4/500 Job: Actuary Assistant, Category: Finance
# [loading saved data] 5/500 Job: Administrative Assistant, Category: Office & Administration
# [loading saved data] 6/500 Job: Advertising Executive, Category: Media and Communication
# [loading saved data] 7/500 Job: Aerospace Engineer, Category: Engineering
# [loading saved data] 8/500 Job: Agricultural Engineer, Category: Engineering
# [loading saved data] 9/500 Job: Air Traffic Controller, Category: Transportation
# [loading saved data] 10/500 Job: Analyst (Business, Financial, Market Research), Category: Business & Finance
# [loading saved data] 11/500 Job: Animator, Category: Arts and Design
# [loading saved data] 12/500 Job: Animator (2D), Category: Arts and Design
# [loading saved data] 13/500 Job: Animator (3D), Category: Arts and Design
# [loading saved data] 14/500 Job: App Developer, Category: Technology
# [loading saved data] 15/500 Job: Application Architect, Category: Technology
# [loading saved data] 16/500 Job: Architect, Category: Construction
# [loading saved data] 17/500 Job: Architect (Landscape), Category: Architecture & Design
# [loading saved data] 18/500 Job: Archivist, Category: Library Science
# [loading saved data] 19/500 Job: Archivist (Digital), Category: Library Science
# [loading saved data] 20/500 Job: Art Director, Category: Arts and Design
# [loading saved data] 21/500 Job: Assistant (Executive, Legal, Medical), Category: Office & Administration
# [loading saved data] 22/500 Job: Astronaut, Category: Science & Technology
# [loading saved data] 23/500 Job: Athlete, Category: Sports & Recreation
# [loading saved data] 24/500 Job: Attorney, Category: Law
# [loading saved data] 25/500 Job: Auditor, Category: Finance
# [loading saved data] 26/500 Job: Author, Category: Arts and Design
# [loading saved data] 27/500 Job: Auto Mechanic, Category: Maintenance & Repair
# [loading saved data] 28/500 Job: Bank Teller, Category: Finance
# [loading saved data] 29/500 Job: Banker, Category: Finance
# [loading saved data] 30/500 Job: Barista, Category: Food & Hospitality
# [loading saved data] 31/500 Job: Bartender, Category: Culinary
# [loading saved data] 32/500 Job: Bioinformatician, Category: Science & Technology
# [loading saved data] 33/500 Job: Biologist, Category: Science
# [loading saved data] 34/500 Job: Biomedical Engineer, Category: Engineering
# [loading saved data] 35/500 Job: Blogger, Category: Media and Communication
# [loading saved data] 36/500 Job: Book Editor, Category: Arts and Design
# [loading saved data] 37/500 Job: Bookkeeper, Category: Finance
# [loading saved data] 38/500 Job: Botanist, Category: Science
# [loading saved data] 39/500 Job: Botanist (Research), Category: Science
# [loading saved data] 40/500 Job: Broadcast Journalist, Category: Media
# [loading saved data] 41/500 Job: Business Analyst, Category: Business & Management
# [loading saved data] 42/500 Job: Business Development Manager, Category: Business & Management
# [loading saved data] 43/500 Job: Butcher, Category: Culinary
# [loading saved data] 44/500 Job: Buyer, Category: Retail & Supply Chain
# [loading saved data] 45/500 Job: Cabinetmaker, Category: Construction & Trades
# [loading saved data] 46/500 Job: CAD Technician, Category: Engineering
# [loading saved data] 47/500 Job: Cashier, Category: Retail
# [loading saved data] 48/500 Job: Cashier (Retail), Category: Retail
# [loading saved data] 49/500 Job: Chef (Executive), Category: Culinary
# [loading saved data] 50/500 Job: Chef (Sous), Category: Culinary
# [loading saved data] 51/500 Job: Chemical Engineer, Category: Engineering
# [loading saved data] 52/500 Job: Chemist, Category: Science
# [loading saved data] 53/500 Job: Chemist (Research), Category: Science
# [loading saved data] 54/500 Job: Chief Executive Officer (CEO), Category: Business & Management
# [loading saved data] 55/500 Job: Chief Financial Officer (CFO), Category: Finance
# [loading saved data] 56/500 Job: Chief Information Officer (CIO), Category: Technology
# [loading saved data] 57/500 Job: Chief Marketing Officer (CMO), Category: Business & Management
# [loading saved data] 58/500 Job: Chief Operating Officer (COO), Category: Business & Management
# [loading saved data] 59/500 Job: Chief Technology Officer (CTO), Category: Technology
# [loading saved data] 60/500 Job: Chiropractor, Category: Healthcare
# [loading saved data] 61/500 Job: Civil Engineer, Category: Construction
# [loading saved data] 62/500 Job: Civil Engineer (Structural), Category: Engineering
# [loading saved data] 63/500 Job: Civil Engineer (Transportation), Category: Engineering
# [loading saved data] 64/500 Job: Claims Adjuster, Category: Insurance
# [loading saved data] 65/500 Job: Clergy, Category: Religion
# [loading saved data] 66/500 Job: Clinical Psychologist, Category: Healthcare
# [loading saved data] 67/500 Job: Clinical Research Coordinator, Category: Healthcare
# [loading saved data] 68/500 Job: Cloud Architect, Category: Technology
# [loading saved data] 69/500 Job: Cloud Engineer, Category: Technology
# [loading saved data] 70/500 Job: Coach (Sports), Category: Sports & Recreation
# [loading saved data] 71/500 Job: Coder, Category: Technology
# [loading saved data] 72/500 Job: Commercial Pilot, Category: Transportation
# [loading saved data] 73/500 Job: Commercial Real Estate Agent, Category: Real Estate
# [loading saved data] 74/500 Job: Compliance Officer, Category: Finance & Legal
# [loading saved data] 75/500 Job: Composer, Category: Arts
# [loading saved data] 76/500 Job: Computer Programmer, Category: Technology
# [loading saved data] 77/500 Job: Computer Science Professor, Category: Education
# [loading saved data] 78/500 Job: Construction Manager, Category: Construction & Trades
# [loading saved data] 79/500 Job: Content Creator, Category: Media and Communication
# [loading saved data] 80/500 Job: Content Manager, Category: Media and Communication
# [loading saved data] 81/500 Job: Cook, Category: Culinary
# [loading saved data] 82/500 Job: Copywriter, Category: Media and Communication
# [loading saved data] 83/500 Job: Cost Accountant, Category: Finance
# [loading saved data] 84/500 Job: Counselor, Category: Social Services
# [loading saved data] 85/500 Job: Counselor (Career), Category: Social Services
# [loading saved data] 86/500 Job: Counselor (Marriage & Family), Category: Social Services
# [loading saved data] 87/500 Job: Counselor (School), Category: Education
# [loading saved data] 88/500 Job: Customer Service Representative, Category: Sales
# [loading saved data] 89/500 Job: Data Analyst, Category: Technology
# [loading saved data] 90/500 Job: Data Entry Clerk, Category: Office & Administration
# [loading saved data] 91/500 Job: Data Scientist, Category: Technology
# [loading saved data] 92/500 Job: Database Administrator, Category: Technology
# [loading saved data] 93/500 Job: Dental Hygienist, Category: Healthcare
# [loading saved data] 94/500 Job: Dentist, Category: Healthcare
# [loading saved data] 95/500 Job: Dentist (Orthodontist), Category: Healthcare
# [loading saved data] 96/500 Job: Dentist (Pediatric), Category: Healthcare
# [loading saved data] 97/500 Job: Dermatologist, Category: Healthcare
# [loading saved data] 98/500 Job: Designer (Fashion), Category: Arts and Design
# [loading saved data] 99/500 Job: Designer (Graphic), Category: Arts and Design
# [loading saved data] 100/500 Job: Designer (Industrial), Category: Engineering & Design
# [loading saved data] 101/500 Job: Designer (Interior), Category: Architecture & Design
# [loading saved data] 102/500 Job: Designer (Product), Category: Engineering & Design
# [loading saved data] 103/500 Job: Designer (UI), Category: Technology
# [loading saved data] 104/500 Job: Designer (User Experience, UX), Category: Technology
# [loading saved data] 105/500 Job: Designer (UX), Category: Technology
# [loading saved data] 106/500 Job: Detective, Category: Law Enforcement
# [loading saved data] 107/500 Job: Developer (Back-End), Category: Technology
# [loading saved data] 108/500 Job: Developer (Front-End), Category: Technology
# [loading saved data] 109/500 Job: Developer (Full Stack), Category: Technology
# [loading saved data] 110/500 Job: Dietitian, Category: Healthcare
# [loading saved data] 111/500 Job: Dietitian (Registered), Category: Healthcare
# [loading saved data] 112/500 Job: Digital Marketer, Category: Business & Marketing
# [loading saved data] 113/500 Job: Diplomat, Category: Government & International Affairs
# [loading saved data] 114/500 Job: Director (Human Resources), Category: Business & Management
# [loading saved data] 115/500 Job: Director (Marketing), Category: Business & Management
# [loading saved data] 116/500 Job: Director (Operations), Category: Business & Management
# [loading saved data] 117/500 Job: Director (Sales), Category: Business & Management
# [loading saved data] 118/500 Job: Director (Technology), Category: Technology
# [loading saved data] 119/500 Job: Dispatcher (Emergency Services), Category: Public Safety
# [loading saved data] 120/500 Job: Dispatcher (Transportation), Category: Transportation
# [loading saved data] 121/500 Job: Doctor (Anesthesiologist), Category: Healthcare
# [loading saved data] 122/500 Job: Doctor (Cardiologist), Category: Healthcare
# [loading saved data] 123/500 Job: Doctor (Dermatologist), Category: Healthcare
# [loading saved data] 124/500 Job: Doctor (Gastroenterologist), Category: Healthcare
# [loading saved data] 125/500 Job: Doctor (General Practitioner), Category: Healthcare
# [loading saved data] 126/500 Job: Doctor (Neurologist), Category: Healthcare
# 127/500 Job: Doctor (Obstetrician/Gynecologist), Category: Healthcare
# Start time: 2024-06-01 14:59:25.495483
# End time: 2024-06-01 15:00:00.048975
# Gemini API request duration: 0:00:34.553492
# [ERROR] 127/500 Job: Doctor (Obstetrician/Gynecologist), Category: Healthcare
# [Errno 2] No such file or directory: 'JOB_TASKS/126_Doctor (Obstetrician/Gynecologist)_Healthcare.csv'
# [loading saved data] 128/500 Job: Doctor (Oncologist), Category: Healthcare
# [loading saved data] 129/500 Job: Doctor (Ophthalmologist), Category: Healthcare
# [loading saved data] 130/500 Job: Doctor (Pediatrician), Category: Healthcare
# [loading saved data] 131/500 Job: Doctor (Psychiatrist), Category: Healthcare
# [loading saved data] 132/500 Job: Doctor (Radiologist), Category: Healthcare
# [loading saved data] 133/500 Job: Doctor (Surgeon, Various Specialities), Category: Healthcare
# [loading saved data] 134/500 Job: Doctor (Various Specialties), Category: Healthcare
# [loading saved data] 135/500 Job: Economist, Category: Social Science
# [loading saved data] 136/500 Job: Editor, Category: Arts and Design
# [loading saved data] 137/500 Job: Editor (Copy), Category: Media and Communication
# [loading saved data] 138/500 Job: Editor (Developmental), Category: Arts and Design
# [loading saved data] 139/500 Job: Editor (Line), Category: Arts and Design
# [loading saved data] 140/500 Job: Editor (Proofreader), Category: Arts and Design
# [loading saved data] 141/500 Job: Educator (Adult), Category: Education
# [loading saved data] 142/500 Job: Educator (Early Childhood), Category: Education
# [loading saved data] 143/500 Job: Engineer (Biomedical), Category: Engineering
# [loading saved data] 144/500 Job: Engineer (Chemical), Category: Engineering
# [loading saved data] 145/500 Job: Engineer (Civil), Category: Engineering
# [loading saved data] 146/500 Job: Engineer (Electrical), Category: Engineering
# [loading saved data] 147/500 Job: Engineer (Environmental), Category: Engineering
# [loading saved data] 148/500 Job: Engineer (Mechanical), Category: Engineering
# [loading saved data] 149/500 Job: Engineer (Software), Category: Technology
# [loading saved data] 150/500 Job: Engineer (Structural), Category: Engineering
# [loading saved data] 151/500 Job: Engineer (Systems), Category: Technology
# [loading saved data] 152/500 Job: Engineer (Various Disciplines), Category: Engineering
# [loading saved data] 153/500 Job: Entrepreneur, Category: Business & Management
# [loading saved data] 154/500 Job: Environmental Consultant, Category: Environmental Science
# [loading saved data] 155/500 Job: Environmental Scientist, Category: Science
# [loading saved data] 156/500 Job: Epidemiologist, Category: Healthcare
# [loading saved data] 157/500 Job: Ergonomist, Category: Engineering & Design
# [loading saved data] 158/500 Job: Event Coordinator, Category: Event Management
# [loading saved data] 159/500 Job: Executive Assistant, Category: Office & Administration
# [loading saved data] 160/500 Job: Exhibit Designer, Category: Museum Science
# [loading saved data] 161/500 Job: Fashion Designer, Category: Arts & Design
# [loading saved data] 162/500 Job: Financial Advisor, Category: Finance
# [loading saved data] 163/500 Job: Financial Analyst, Category: Finance
# [loading saved data] 164/500 Job: Financial Analyst (Investment), Category: Finance
# [loading saved data] 165/500 Job: Financial Planner, Category: Finance
# [loading saved data] 166/500 Job: Fire Chief, Category: Public Safety
# [loading saved data] 167/500 Job: Fire Inspector, Category: Public Safety
# [loading saved data] 168/500 Job: Firefighter, Category: Public Safety
# [loading saved data] 169/500 Job: First Responder (EMT, Paramedic), Category: Healthcare
# [loading saved data] 170/500 Job: Fitness Instructor, Category: Sports & Recreation
# [loading saved data] 171/500 Job: Flight Attendant, Category: Transportation
# [loading saved data] 172/500 Job: Flight Instructor, Category: Transportation
# [loading saved data] 173/500 Job: Florist, Category: Agriculture & Retail
# [loading saved data] 174/500 Job: Food Blogger, Category: Media and Communication
# [loading saved data] 175/500 Job: Food Scientist, Category: Science
# [loading saved data] 176/500 Job: Food Stylist, Category: Culinary
# [loading saved data] 177/500 Job: Forensic Scientist, Category: Science & Law Enforcement
# [loading saved data] 178/500 Job: Forester, Category: Environmental Science
# [loading saved data] 179/500 Job: Forester (Research), Category: Environmental Science
# [loading saved data] 180/500 Job: Front-End Developer, Category: Technology
# [loading saved data] 181/500 Job: Game Designer, Category: Technology
# [loading saved data] 182/500 Job: Geneticist, Category: Science
# [loading saved data] 183/500 Job: Geologist, Category: Science
# [loading saved data] 184/500 Job: Geologist (Exploration), Category: Science
# [loading saved data] 185/500 Job: Graphic Designer, Category: Arts and Design
# [loading saved data] 186/500 Job: Graphic Designer (Print), Category: Arts and Design
# [loading saved data] 187/500 Job: Graphic Designer (Web), Category: Technology
# [loading saved data] 188/500 Job: Health Educator, Category: Healthcare
# [loading saved data] 189/500 Job: Healthcare Administrator, Category: Healthcare
# [loading saved data] 190/500 Job: Historian, Category: History & Information
# [loading saved data] 191/500 Job: Historian (Research), Category: History & Information
# [loading saved data] 192/500 Job: Home Health Aide, Category: Healthcare
# [loading saved data] 193/500 Job: Home Stager, Category: Real Estate
# [loading saved data] 194/500 Job: Human Resources Manager, Category: Business & Management
# [loading saved data] 195/500 Job: Human Resources Specialist, Category: Business & Management
# [loading saved data] 196/500 Job: Illustrator, Category: Arts and Design
# [loading saved data] 197/500 Job: Industrial Designer, Category: Engineering & Design
# [loading saved data] 198/500 Job: Information Security Analyst, Category: Technology
# [loading saved data] 199/500 Job: Insurance Agent, Category: Finance
# [loading saved data] 200/500 Job: Insurance Broker, Category: Finance
# [loading saved data] 201/500 Job: Insurance Underwriter, Category: Finance
# [loading saved data] 202/500 Job: Interior Designer, Category: Architecture & Design
# [loading saved data] 203/500 Job: Interior Designer (Commercial), Category: Architecture & Design
# [loading saved data] 204/500 Job: Interpreter, Category: Language & Communication
# [loading saved data] 205/500 Job: Interpreter (Legal), Category: Law
# [loading saved data] 206/500 Job: Interpreter (Medical), Category: Healthcare
# [loading saved data] 207/500 Job: Investment Analyst, Category: Finance
# [loading saved data] 208/500 Job: Investment Banker, Category: Finance
# [loading saved data] 209/500 Job: Investment Manager, Category: Finance
# [loading saved data] 210/500 Job: IT Architect, Category: Technology
# [loading saved data] 211/500 Job: IT Manager, Category: Technology
# [loading saved data] 212/500 Job: IT Support Specialist, Category: Technology
# [loading saved data] 213/500 Job: Journalist, Category: Media
# [loading saved data] 214/500 Job: Journalist (Investigative), Category: Media
# [loading saved data] 215/500 Job: Journalist (Sports), Category: Media
# [loading saved data] 216/500 Job: Judge, Category: Law
# [loading saved data] 217/500 Job: Lab Technician (Chemistry), Category: Science
# [loading saved data] 218/500 Job: Lab Technician (Medical), Category: Healthcare
# [loading saved data] 219/500 Job: Laboratory Technician, Category: Science
# [loading saved data] 220/500 Job: Laborer (Construction), Category: Construction & Trades
# [loading saved data] 221/500 Job: Landscape Architect, Category: Architecture & Design
# [loading saved data] 222/500 Job: Landscape Architect (Commercial), Category: Architecture & Design
# [loading saved data] 223/500 Job: Landscape Architect (Residential), Category: Architecture & Design
# [loading saved data] 224/500 Job: Lawyer, Category: Law
# [loading saved data] 225/500 Job: Lawyer (Corporate), Category: Law
# [loading saved data] 226/500 Job: Lawyer (Criminal), Category: Law
# [loading saved data] 227/500 Job: Lawyer (Environmental), Category: Law
# [loading saved data] 228/500 Job: Lawyer (Family), Category: Law
# [loading saved data] 229/500 Job: Lawyer (Intellectual Property), Category: Law
# [loading saved data] 230/500 Job: Lawyer (Tax), Category: Law
# [loading saved data] 231/500 Job: Librarian, Category: Library Science
# [loading saved data] 232/500 Job: Librarian (Special Collections), Category: Library Science
# [loading saved data] 233/500 Job: Loan Officer, Category: Finance
# [loading saved data] 234/500 Job: Loan Officer (Mortgage), Category: Finance
# [loading saved data] 235/500 Job: Logistician, Category: Transportation & Logistics
# [loading saved data] 236/500 Job: Machine Learning Engineer, Category: Technology
# [loading saved data] 237/500 Job: Machinist, Category: Skilled Trades
# [loading saved data] 238/500 Job: Management Consultant, Category: Business & Management
# [loading saved data] 239/500 Job: Manager (Various Industries), Category: Business & Management
# [loading saved data] 240/500 Job: Market Research Analyst, Category: Business & Marketing
# [loading saved data] 241/500 Job: Marketing Coordinator, Category: Business & Marketing
# [loading saved data] 242/500 Job: Marketing Manager, Category: Business & Management
# [loading saved data] 243/500 Job: Marketing Specialist (Digital), Category: Business & Marketing
# [loading saved data] 244/500 Job: Marketing Specialist (Email), Category: Business & Marketing
# [loading saved data] 245/500 Job: Marketing Specialist (Social Media), Category: Business & Marketing
# [loading saved data] 246/500 Job: Materials Scientist, Category: Science & Engineering
# [loading saved data] 247/500 Job: Mathematician, Category: Mathematics & Science
# [loading saved data] 248/500 Job: Mathematician (Actuarial), Category: Finance & Mathematics
# [loading saved data] 249/500 Job: Mathematician (Applied), Category: Science & Engineering
# [loading saved data] 250/500 Job: Mechanic (Auto, Airplane, etc.), Category: Maintenance & Repair
# [loading saved data] 251/500 Job: Mechanical Engineer, Category: Engineering
# [loading saved data] 252/500 Job: Media Planner, Category: Media and Communication
# [loading saved data] 253/500 Job: Medical Assistant, Category: Healthcare
# [loading saved data] 254/500 Job: Medical Billing Specialist, Category: Healthcare
# [loading saved data] 255/500 Job: Medical Coder, Category: Healthcare
# [loading saved data] 256/500 Job: Medical Illustrator, Category: Healthcare & Arts
# [loading saved data] 257/500 Job: Medical Physicist, Category: Healthcare & Science
# [loading saved data] 258/500 Job: Medical Secretary, Category: Healthcare
# [loading saved data] 259/500 Job: Medical Technician, Category: Healthcare
# [loading saved data] 260/500 Job: Medical Writer, Category: Healthcare
# [loading saved data] 261/500 Job: Meteorologist, Category: Science
# [loading saved data] 262/500 Job: Microbiologist, Category: Science
# [loading saved data] 263/500 Job: Military Intelligence Analyst, Category: Military
# [loading saved data] 264/500 Job: Military Officer, Category: Military
# [loading saved data] 265/500 Job: Military Personnel, Category: Military & Defense
# [loading saved data] 266/500 Job: Miner, Category: Mining & Extraction
# [loading saved data] 267/500 Job: Museum Curator, Category: Museum Science
# [loading saved data] 268/500 Job: Music Producer, Category: Arts
# [loading saved data] 269/500 Job: Music Teacher, Category: Education
# [loading saved data] 270/500 Job: Network Administrator, Category: Technology
# [loading saved data] 271/500 Job: Network Engineer, Category: Technology
# [loading saved data] 272/500 Job: Nurse, Category: Healthcare
# [loading saved data] 273/500 Job: Nurse (Certified Nursing Assistant, CNA), Category: Healthcare
# [loading saved data] 274/500 Job: Nurse (Licensed Practical, LPN), Category: Healthcare
# [loading saved data] 275/500 Job: Nurse (Registered, RN), Category: Healthcare
# [loading saved data] 276/500 Job: Nurse Practitioner (NP), Category: Healthcare
# [loading saved data] 277/500 Job: Nutritionist, Category: Healthcare
# [loading saved data] 278/500 Job: Nutritionist (Sports), Category: Sports & Healthcare
# [loading saved data] 279/500 Job: Occupational Therapist, Category: Healthcare
# [loading saved data] 280/500 Job: Occupational Therapist (Hand), Category: Healthcare
# [loading saved data] 281/500 Job: Occupational Therapist (Pediatric), Category: Healthcare
# [loading saved data] 282/500 Job: Office Manager, Category: Office & Administration
# [loading saved data] 283/500 Job: Operations Analyst, Category: Business & Management
# [loading saved data] 284/500 Job: Operations Manager, Category: Business & Management
# [loading saved data] 285/500 Job: Optician, Category: Healthcare
# [loading saved data] 286/500 Job: Optometrist, Category: Healthcare
# [loading saved data] 287/500 Job: Optometrist (Pediatric), Category: Healthcare
# [loading saved data] 288/500 Job: Orthodontist, Category: Healthcare
# [loading saved data] 289/500 Job: Painter (Artist), Category: Arts
# [loading saved data] 290/500 Job: Painter (Construction), Category: Construction & Trades
# [loading saved data] 291/500 Job: Paralegal, Category: Law
# [loading saved data] 292/500 Job: Paralegal (Corporate), Category: Law
# [loading saved data] 293/500 Job: Paralegal (Criminal), Category: Law
# [loading saved data] 294/500 Job: Paramedic, Category: Healthcare
# [loading saved data] 295/500 Job: Pastor, Category: Religion
# [loading saved data] 296/500 Job: Patent Attorney, Category: Law
# [loading saved data] 297/500 Job: Payroll Specialist, Category: Finance
# [loading saved data] 298/500 Job: Pediatrician, Category: Healthcare
# [loading saved data] 299/500 Job: Personal Trainer, Category: Sports & Recreation
# [loading saved data] 300/500 Job: Pharmacist, Category: Healthcare
# [loading saved data] 301/500 Job: Pharmacist (Clinical), Category: Healthcare
# [loading saved data] 302/500 Job: Photographer, Category: Arts and Design
# [loading saved data] 303/500 Job: Photographer (Commercial), Category: Arts and Design
# [loading saved data] 304/500 Job: Photographer (Fashion), Category: Arts and Design
# [loading saved data] 305/500 Job: Photographer (Wedding), Category: Arts and Design
# [loading saved data] 306/500 Job: Physical Therapist, Category: Healthcare
# [loading saved data] 307/500 Job: Physician (Various Specialties), Category: Healthcare
# [loading saved data] 308/500 Job: Physician Assistant (PA), Category: Healthcare
# [loading saved data] 309/500 Job: Physicist (Experimental), Category: Science
# [loading saved data] 310/500 Job: Physicist (Theoretical), Category: Science
# [loading saved data] 311/500 Job: Pilot (Airline), Category: Transportation
# [loading saved data] 312/500 Job: Pilot (Commercial, Private), Category: Transportation
# [loading saved data] 313/500 Job: Pilot (Corporate), Category: Transportation
# [loading saved data] 314/500 Job: Pilot (Helicopter), Category: Transportation
# [loading saved data] 315/500 Job: Pilot (Military), Category: Military
# [loading saved data] 316/500 Job: Plant Biologist, Category: Science
# [loading saved data] 317/500 Job: Podiatrist, Category: Healthcare
# [loading saved data] 318/500 Job: Police Detective, Category: Law Enforcement
# [loading saved data] 319/500 Job: Police Officer, Category: Law Enforcement
# [loading saved data] 320/500 Job: Political Scientist, Category: Social Science
# [loading saved data] 321/500 Job: Politician, Category: Government & Politics
# [loading saved data] 322/500 Job: Portfolio Manager, Category: Finance
# [loading saved data] 323/500 Job: Postal Worker, Category: Transportation & Logistics
# [loading saved data] 324/500 Job: Product Designer, Category: Technology
# [loading saved data] 325/500 Job: Product Manager, Category: Technology
# [loading saved data] 326/500 Job: Product Manager, Category: Technology
# [loading saved data] 327/500 Job: Professor, Category: Education
# [loading saved data] 328/500 Job: Programmer, Category: Technology
# [loading saved data] 329/500 Job: Project Manager (Construction), Category: Construction
# [loading saved data] 330/500 Job: Project Manager (IT), Category: Technology
# [loading saved data] 331/500 Job: Project Manager (Marketing), Category: Business & Marketing
# [loading saved data] 332/500 Job: Psychiatrist, Category: Healthcare
# [loading saved data] 333/500 Job: Psychologist, Category: Social Services
# [loading saved data] 334/500 Job: Psychologist (Clinical), Category: Social Services
# [loading saved data] 335/500 Job: Psychologist (Developmental), Category: Social Services
# [loading saved data] 336/500 Job: Psychologist (Forensic), Category: Social Services & Law Enforcement
# 337/500 Job: Psychologist (Industrial/Organizational), Category: Business & Psychology
# Start time: 2024-06-01 15:00:00.066989
# End time: 2024-06-01 15:01:01.175025
# Gemini API request duration: 0:01:01.108036
# [ERROR] 337/500 Job: Psychologist (Industrial/Organizational), Category: Business & Psychology
# [Errno 2] No such file or directory: 'JOB_TASKS/336_Psychologist (Industrial/Organizational)_Business & Psychology.csv'
# [loading saved data] 338/500 Job: Public Relations Manager, Category: Business & Communication
# [loading saved data] 339/500 Job: Public Relations Specialist, Category: Business & Communication
# [loading saved data] 340/500 Job: Quality Assurance Analyst, Category: Technology
# [loading saved data] 341/500 Job: Quantity Surveyor, Category: Construction
# [loading saved data] 342/500 Job: Radiologist, Category: Healthcare
# [loading saved data] 343/500 Job: Real Estate Agent, Category: Sales
# [loading saved data] 344/500 Job: Real Estate Appraiser, Category: Real Estate
# [loading saved data] 345/500 Job: Real Estate Developer, Category: Real Estate
# [loading saved data] 346/500 Job: Receptionist, Category: Office & Administration
# [loading saved data] 347/500 Job: Receptionist (Corporate), Category: Office & Administration
# [loading saved data] 348/500 Job: Receptionist (Legal), Category: Law
# [loading saved data] 349/500 Job: Receptionist (Medical), Category: Healthcare
# [loading saved data] 350/500 Job: Recruiter, Category: Human Resources
# [loading saved data] 351/500 Job: Registered Dietitian, Category: Healthcare
# [loading saved data] 352/500 Job: Registered Nurse (RN), Category: Healthcare
# [loading saved data] 353/500 Job: Reporter, Category: Media
# [loading saved data] 354/500 Job: Research Scientist, Category: Science
# [loading saved data] 355/500 Job: Researcher (Various Fields), Category: Science & Academia
# [loading saved data] 356/500 Job: Restaurant Manager, Category: Culinary
# [loading saved data] 357/500 Job: Retail Buyer, Category: Retail & Supply Chain
# [loading saved data] 358/500 Job: Retail Manager (Assistant), Category: Retail
# [loading saved data] 359/500 Job: Retail Sales Associate, Category: Retail
# [loading saved data] 360/500 Job: Risk Manager, Category: Finance
# [loading saved data] 361/500 Job: Robotics Engineer, Category: Engineering
# [loading saved data] 362/500 Job: Sales Manager, Category: Sales
# [loading saved data] 363/500 Job: Sales Representative, Category: Sales
# [loading saved data] 364/500 Job: Sales Representative (Inside), Category: Sales
# [loading saved data] 365/500 Job: Sales Representative (Outside), Category: Sales
# [loading saved data] 366/500 Job: School Administrator, Category: Education
# [loading saved data] 367/500 Job: School Counselor, Category: Education
# [loading saved data] 368/500 Job: Scientist, Category: Science
# [loading saved data] 369/500 Job: Scientist (Data), Category: Science & Technology
# [loading saved data] 370/500 Job: Scientist (Environmental), Category: Science
# [loading saved data] 371/500 Job: Scientist (Materials), Category: Science & Engineering
# [loading saved data] 372/500 Job: Scientist (Research), Category: Science
# [loading saved data] 373/500 Job: Secretary (Legal), Category: Law
# [loading saved data] 374/500 Job: Secretary (Medical), Category: Healthcare
# [loading saved data] 375/500 Job: Security Analyst (Cyber), Category: Technology
# [loading saved data] 376/500 Job: Security Guard, Category: Security
# [loading saved data] 377/500 Job: Social Media Manager, Category: Business & Marketing
# [loading saved data] 378/500 Job: Social Worker, Category: Social Services
# [loading saved data] 379/500 Job: Software Architect, Category: Technology
# [loading saved data] 380/500 Job: Software Developer, Category: Technology
# [loading saved data] 381/500 Job: Software Engineer, Category: Technology
# [loading saved data] 382/500 Job: Software Tester, Category: Technology
# [loading saved data] 383/500 Job: Solicitor, Category: Law
# [loading saved data] 384/500 Job: Sound Engineer, Category: Performing Arts
# [loading saved data] 385/500 Job: Sports Agent, Category: Sports & Business
# [loading saved data] 386/500 Job: Statistician, Category: Mathematics & Science
# [loading saved data] 387/500 Job: Statistician (Data Analyst), Category: Mathematics & Science
# [loading saved data] 388/500 Job: Stock Analyst, Category: Finance
# [loading saved data] 389/500 Job: Stockbroker, Category: Finance
# [loading saved data] 390/500 Job: Structural Engineer, Category: Engineering
# [loading saved data] 391/500 Job: Surveyor, Category: Construction
# [loading saved data] 392/500 Job: Systems Administrator, Category: Technology
# [loading saved data] 393/500 Job: Tax Accountant, Category: Finance
# [loading saved data] 394/500 Job: Tax Preparer, Category: Finance
# [loading saved data] 395/500 Job: Teacher (Elementary), Category: Education
# [loading saved data] 396/500 Job: Teacher (High School), Category: Education
# [loading saved data] 397/500 Job: Teacher (Special Education), Category: Education
# [loading saved data] 398/500 Job: Teacher (Various Subjects), Category: Education
# [loading saved data] 399/500 Job: Technician (Various Fields), Category: Technology & Skilled Trades
# [loading saved data] 400/500 Job: Therapist (Various Specialties), Category: Healthcare
# [loading saved data] 401/500 Job: Tour Guide, Category: Tourism & Hospitality
# [loading saved data] 402/500 Job: Translator, Category: Language & Communication
# [loading saved data] 403/500 Job: Travel Agent, Category: Tourism & Hospitality
# [loading saved data] 404/500 Job: UI Designer, Category: Technology
# [loading saved data] 405/500 Job: Urban Planner, Category: Social Services
# [loading saved data] 406/500 Job: UX Designer, Category: Technology
# [loading saved data] 407/500 Job: Veterinarian, Category: Healthcare
# [loading saved data] 408/500 Job: Veterinarian (Farm), Category: Agriculture
# [loading saved data] 409/500 Job: Video Game Designer, Category: Technology
# [loading saved data] 410/500 Job: Web Designer, Category: Technology
# [loading saved data] 411/500 Job: Web Developer, Category: Technology
# [loading saved data] 412/500 Job: Writer, Category: Arts and Design
# [loading saved data] 413/500 Job: Account Manager, Category: Business & Management
# [loading saved data] 414/500 Job: Accountant, Category: Finance
# [loading saved data] 415/500 Job: Actuary, Category: Finance
# [loading saved data] 416/500 Job: Actuary Assistant, Category: Finance
# [loading saved data] 417/500 Job: Administrative Assistant, Category: Office & Administration
# [loading saved data] 418/500 Job: Advertising Executive, Category: Media and Communication
# [loading saved data] 419/500 Job: Aerospace Engineer, Category: Engineering
# [loading saved data] 420/500 Job: Agricultural Engineer, Category: Engineering
# [loading saved data] 421/500 Job: Air Traffic Controller, Category: Transportation
# [loading saved data] 422/500 Job: Analyst (Business, Financial, Market Research), Category: Business & Finance
# [loading saved data] 423/500 Job: Animator, Category: Arts and Design
# [loading saved data] 424/500 Job: Animator (2D), Category: Arts and Design
# [loading saved data] 425/500 Job: Animator (3D), Category: Arts and Design
# [loading saved data] 426/500 Job: App Developer, Category: Technology
# [loading saved data] 427/500 Job: Application Architect, Category: Technology
# [loading saved data] 428/500 Job: Architect, Category: Construction
# [loading saved data] 429/500 Job: Architect (Landscape), Category: Architecture & Design
# [loading saved data] 430/500 Job: Archivist, Category: Library Science
# [loading saved data] 431/500 Job: Archivist (Digital), Category: Library Science
# [loading saved data] 432/500 Job: Art Director, Category: Arts and Design
# [loading saved data] 433/500 Job: Assistant (Executive, Legal, Medical), Category: Office & Administration
# [loading saved data] 434/500 Job: Astronaut, Category: Science & Technology
# [loading saved data] 435/500 Job: Athlete, Category: Sports & Recreation
# [loading saved data] 436/500 Job: Attorney, Category: Law
# [loading saved data] 437/500 Job: Auditor, Category: Finance
# [loading saved data] 438/500 Job: Author, Category: Arts and Design
# [loading saved data] 439/500 Job: Auto Mechanic, Category: Maintenance & Repair
# [loading saved data] 440/500 Job: Bank Teller, Category: Finance
# [loading saved data] 441/500 Job: Banker, Category: Finance
# [loading saved data] 442/500 Job: Barista, Category: Food & Hospitality
# [loading saved data] 443/500 Job: Bartender, Category: Culinary
# [loading saved data] 444/500 Job: Bioinformatician, Category: Science & Technology
# [loading saved data] 445/500 Job: Biologist, Category: Science
# [loading saved data] 446/500 Job: Biomedical Engineer, Category: Engineering
# [loading saved data] 447/500 Job: Blogger, Category: Media and Communication
# [loading saved data] 448/500 Job: Book Editor, Category: Arts and Design
# [loading saved data] 449/500 Job: Bookkeeper, Category: Finance
# [loading saved data] 450/500 Job: Botanist, Category: Science
# [loading saved data] 451/500 Job: Botanist (Research), Category: Science
# [loading saved data] 452/500 Job: Broadcast Journalist, Category: Media
# [loading saved data] 453/500 Job: Business Analyst, Category: Business & Management
# [loading saved data] 454/500 Job: Business Development Manager, Category: Business & Management
# [loading saved data] 455/500 Job: Butcher, Category: Culinary
# [loading saved data] 456/500 Job: Buyer, Category: Retail & Supply Chain
# [loading saved data] 457/500 Job: Cabinetmaker, Category: Construction & Trades
# [loading saved data] 458/500 Job: CAD Technician, Category: Engineering
# [loading saved data] 459/500 Job: Cashier, Category: Retail
# [loading saved data] 460/500 Job: Cashier (Retail), Category: Retail
# [loading saved data] 461/500 Job: Chef (Executive), Category: Culinary
# [loading saved data] 462/500 Job: Chef (Sous), Category: Culinary
# [loading saved data] 463/500 Job: Chemical Engineer, Category: Engineering
# [loading saved data] 464/500 Job: Chemist, Category: Science
# [loading saved data] 465/500 Job: Chemist (Research), Category: Science
# [loading saved data] 466/500 Job: Chief Executive Officer (CEO), Category: Business & Management
# [loading saved data] 467/500 Job: Chief Financial Officer (CFO), Category: Finance
# [loading saved data] 468/500 Job: Chief Information Officer (CIO), Category: Technology
# [loading saved data] 469/500 Job: Chief Marketing Officer (CMO), Category: Business & Management
# [loading saved data] 470/500 Job: Chief Operating Officer (COO), Category: Business & Management
# [loading saved data] 471/500 Job: Chief Technology Officer (CTO), Category: Technology
# [loading saved data] 472/500 Job: Chiropractor, Category: Healthcare
# [loading saved data] 473/500 Job: Civil Engineer, Category: Construction
# [loading saved data] 474/500 Job: Civil Engineer (Structural), Category: Engineering
# [loading saved data] 475/500 Job: Civil Engineer (Transportation), Category: Engineering
# [loading saved data] 476/500 Job: Claims Adjuster, Category: Insurance
# [loading saved data] 477/500 Job: Clergy, Category: Religion
# [loading saved data] 478/500 Job: Clinical Psychologist, Category: Healthcare
# [loading saved data] 479/500 Job: Clinical Research Coordinator, Category: Healthcare
# [loading saved data] 480/500 Job: Cloud Architect, Category: Technology
# [loading saved data] 481/500 Job: Cloud Engineer, Category: Technology
# [loading saved data] 482/500 Job: Coach (Sports), Category: Sports & Recreation
# [loading saved data] 483/500 Job: Coder, Category: Technology
# [loading saved data] 484/500 Job: Commercial Pilot, Category: Transportation
# [loading saved data] 485/500 Job: Commercial Real Estate Agent, Category: Real Estate
# [loading saved data] 486/500 Job: Compliance Officer, Category: Finance & Legal
# [loading saved data] 487/500 Job: Composer, Category: Arts
# [loading saved data] 488/500 Job: Computer Programmer, Category: Technology
# [loading saved data] 489/500 Job: Computer Science Professor, Category: Education
# [loading saved data] 490/500 Job: Construction Manager, Category: Construction & Trades
# [loading saved data] 491/500 Job: Content Creator, Category: Media and Communication
# [loading saved data] 492/500 Job: Content Manager, Category: Media and Communication
# [loading saved data] 493/500 Job: Cook, Category: Culinary
# [loading saved data] 494/500 Job: Copywriter, Category: Media and Communication
# [loading saved data] 495/500 Job: Cost Accountant, Category: Finance
# [loading saved data] 496/500 Job: Counselor, Category: Social Services
# [loading saved data] 497/500 Job: Counselor (Career), Category: Social Services
# [loading saved data] 498/500 Job: Counselor (Marriage & Family), Category: Social Services
# [loading saved data] 499/500 Job: Counselor (School), Category: Education
# [loading saved data] 500/500 Job: Customer Service Representative, Category: Sales

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero
