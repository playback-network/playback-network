# %%
API_KEY = 'REDACTED'

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import google.generativeai as genai
from datetime import datetime
import csv
import re

# %% [markdown]
# # Prompt

# %%
def get_prompt(df):
    return f"""
            rewrite this table so that the examples:
            * include reference to a specific app to use to complete the Example Task
            * are self-contained and do not refer to any context that is outside of the task
            * are specific tasks that a person can complete on a computer in under 3 minutes
            * all the detail should be given in the task example for a person to execute the task
            * a task like "Track recruiting department budget in a spreadsheet" is bad because it's not specific - make all examples specific so a person can execute the task themselves without needing to ask questions or get specifics
            * all examples should be under 15 words and be as concise as possible
            * delete any examples that are too vague to be done by a random stranger based on the example
            * combine examples so that the resulting table has fewer rows than the input table
            * where multiple rows do the same task, pick the job most commonly associated with the example
            * return just a rewritten table

        {df}
        

    """

# %%
df = pd.read_csv('tasks_filtered_clean.csv')

# %%
categories = list(df['Category'].unique())

# %%
len(categories)
# Out:
# 496

# %% [markdown]
# # Setup Gemini

# %%
genai.configure(api_key=API_KEY)

generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE",
    },
]

# %% [markdown]
# # Use gemini to get tasks for each job

# %%
index = 0

# %%
dft = df[df['Category'] == category]

PROMPT = get_prompt(dft.to_csv(index=False))

# output csv of tasks for this job
FILENAME = f'TASKS_REWRITTEN/{category}.csv'

# %%
model = None

# get jobs CSV using gemini
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    safety_settings=safety_settings,
    generation_config=generation_config,
)

start_time = datetime.now()
print(f"Start time: {start_time}")

chat_session = model.start_chat(
    history=[
        {
            "role": "user",
            "parts": [
                PROMPT,
            ],
        }
    ]
)

response = chat_session.send_message("Produce new TABLE as per the instructions above.")
end_time = datetime.now()
duration = end_time - start_time

print(f"End time: {end_time}")
print(f"Gemini API request duration: {duration}")
# Out:
# Start time: 2024-06-01 23:15:54.606136
# End time: 2024-06-01 23:16:00.320331
# Gemini API request duration: 0:00:05.714195

# %%
# Out:
# ['| Job | Category | Example |',
#  '|---|---|---|',
#  '| Barista | Accounting | Record a purchase of milk and coffee beans in QuickBooks. |',
#  '| Chef (Executive) | Accounting | View a QuickBooks report for restaurant income and expenses this month. |',
#  '| Chemical Engineer | Accounting | Record chemical purchase in Xero. |',
#  '| Chemist | Accounting | Record lab supply expenses in Xero. |',
#  '| Chief Executive Officer (CEO) | Accounting | Generate a Xero financial report for a board meeting. |',
#  '| Chief Information Officer (CIO) | Accounting | Track IT asset depreciation in Excel. |',
#  '| Cook | Accounting | Record a payment to "John\'s Produce" in QuickBooks. | ',
#  '| Director (Technology) | Accounting | Manage technology service invoices in QuickBooks. |',
#  '| Doctor (Anesthesiologist) | Accounting | Manage anesthesia service invoices in QuickBooks. |',
#  '| Graphic Designer (Print) | Accounting | Record Adobe Creative Cloud subscription cost in your accounting software. |',
#  '| Human Resources Manager | Accounting | Record a payment to an HR consulting service in Xero. |',
#  '| IT Manager | Accounting | Record new laptop purchases for employees in QuickBooks. |',
#  '| Medical Secretary | Accounting | Track practice expenses for a specific month in Google Sheets. |',
#  '| Military Officer | Accounting | Track budget expenditures for a military unit in DFAS. |',
#  '| Pastor | Accounting | Generate a financial report for the church council in Xero. |',
#  '| Plant Biologist | Accounting | Summarize research project financials in Excel. |',
#  '| Recruiter | Accounting | Track recruiting department budget in a spreadsheet. | ',
#  '| Teacher (Various Subjects) | Accounting | Track student fees and payments for extracurricular activities in Google Sheets. | ',
#  "| Teacher (Various Subjects) | Accounting | View your department's budget balance in the school's budgeting software. |"]

# %%
# Remove extra newlines and split the response text into lines
lines = response.text.strip().split("\n")

# Extract the header and rows
header = re.split(r'\s*\|\s*', lines[0].strip('|'))
rows = [re.split(r'\s*\|\s*', line.strip('|')) for line in lines[2:]]

# Write to CSV
with open(FILENAME, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(header)
    csvwriter.writerows(rows)

# %%
from time import sleep

# %%
for index, category in enumerate(categories):

    dft = df[df['Category'] == category]
    
    PROMPT = get_prompt(dft.to_csv(index=False))
    
    # output csv of tasks for this job
    FILENAME = f'TASKS_REWRITTEN/{category}.csv'

    #print(PROMPT)

    # skip if already done
    if os.path.exists(FILENAME):
        print(f"[loading saved data] {index+1}/{len(categories)} Category: {category}")
    else:
        print(f"{index+1}/{len(categories)} Category: {category}")

        try:
            model = None
            
            # get jobs CSV using gemini
            model = genai.GenerativeModel(
                model_name="gemini-1.5-flash",
                safety_settings=safety_settings,
                generation_config=generation_config,
            )
            
            start_time = datetime.now()
            print(f"Start time: {start_time}")
            
            chat_session = model.start_chat(
                history=[
                    {
                        "role": "user",
                        "parts": [
                            PROMPT,
                        ],
                    }
                ]
            )
            
            response = chat_session.send_message("Produce new TABLE as per the instructions above.")
            end_time = datetime.now()
            duration = end_time - start_time
            
            print(f"End time: {end_time}")
            print(f"Gemini API request duration: {duration}")
        
            # Remove extra newlines and split the response text into lines
            lines = response.text.strip().split('\n')
            
            # Extract the header and rows
            header = re.split(r'\s*\|\s*', lines[0].strip('|'))
            rows = [re.split(r'\s*\|\s*', line.strip('|')) for line in lines[2:]]
            
            # Write to CSV
            with open(FILENAME, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
        
            print("Saving file")
            sleep(2)
        except Exception as e:
            print(f"[ERROR] {index+1}/{len(categories)} Category: {category}")
            print(e)
# Out:
# [loading saved data] 1/496 Category: 2D Art
# [loading saved data] 2/496 Category: 3D Modeling
# [loading saved data] 3/496 Category: 3D Printing
# [loading saved data] 4/496 Category: Abstract Algebra
# [loading saved data] 5/496 Category: Accessibility
# [loading saved data] 6/496 Category: Accounting
# [loading saved data] 7/496 Category: Acting
# [loading saved data] 8/496 Category: Actuarial Science
# [loading saved data] 9/496 Category: Administration
# [loading saved data] 10/496 Category: Administrative Tasks
# [loading saved data] 11/496 Category: Agile
# [loading saved data] 12/496 Category: Agile Development
# [loading saved data] 13/496 Category: Agricultural Genetics
# [loading saved data] 14/496 Category: Agriculture
# [loading saved data] 15/496 Category: AI & Machine Learning
# [loading saved data] 16/496 Category: Algebra
# [loading saved data] 17/496 Category: Analysis
# [loading saved data] 18/496 Category: Analytics
# [loading saved data] 19/496 Category: Animation
# [loading saved data] 20/496 Category: API Integration
# [loading saved data] 21/496 Category: Appeals
# [loading saved data] 22/496 Category: Architecture
# [loading saved data] 23/496 Category: Architecture & Design
# [loading saved data] 24/496 Category: Art Direction
# [loading saved data] 25/496 Category: Artificial Intelligence
# [loading saved data] 26/496 Category: Artificial Intelligence (AI)
# [loading saved data] 27/496 Category: Arts and Design
# [loading saved data] 28/496 Category: Audio Editing
# [loading saved data] 29/496 Category: Audio Recording
# [loading saved data] 30/496 Category: Augmented Reality (AR)
# [loading saved data] 31/496 Category: Auto Repair Software
# [loading saved data] 32/496 Category: Automation
# [loading saved data] 33/496 Category: Automation & Control Systems
# [loading saved data] 34/496 Category: Automation & Scripting
# [loading saved data] 35/496 Category: Backend Development
# [loading saved data] 36/496 Category: Backup & Recovery
# [loading saved data] 37/496 Category: Billing
# [loading saved data] 38/496 Category: Billing & Coding
# [loading saved data] 39/496 Category: Billing and Coding
# [loading saved data] 40/496 Category: Bioinformatics
# [loading saved data] 41/496 Category: Biomechanics
# [loading saved data] 42/496 Category: Biomedical Engineering
# [loading saved data] 43/496 Category: Biotechnology
# [loading saved data] 44/496 Category: Blockchain
# [loading saved data] 45/496 Category: Blockchain & Cryptocurrency
# [loading saved data] 46/496 Category: Booking
# [loading saved data] 47/496 Category: Brand Management
# [loading saved data] 48/496 Category: Broadcast News
# [loading saved data] 49/496 Category: Business
# [loading saved data] 50/496 Category: Business & Management
# [loading saved data] 51/496 Category: Business & Marketing
# [loading saved data] 52/496 Category: Business Analysis
# [loading saved data] 53/496 Category: Business Analytics
# [loading saved data] 54/496 Category: Business Development
# [loading saved data] 55/496 Category: Business Intelligence
# [loading saved data] 56/496 Category: Business Process Management
# [loading saved data] 57/496 Category: CAD
# [loading saved data] 58/496 Category: CAD Design
# [loading saved data] 59/496 Category: Calculus
# [loading saved data] 60/496 Category: Calendar
# [loading saved data] 61/496 Category: Calendar Management
# [loading saved data] 62/496 Category: Case Management
# [loading saved data] 63/496 Category: Cataloging
# [loading saved data] 64/496 Category: Change Management
# [loading saved data] 65/496 Category: Chemical Engineering
# [loading saved data] 66/496 Category: Chemical Science
# [loading saved data] 67/496 Category: Civil Engineering
# [loading saved data] 68/496 Category: Claims Management
# [loading saved data] 69/496 Category: Client Communication
# [loading saved data] 70/496 Category: Client Management
# [loading saved data] 71/496 Category: Clinical Research
# [loading saved data] 72/496 Category: Cloud
# [loading saved data] 73/496 Category: Cloud Adoption
# [loading saved data] 74/496 Category: Cloud Applications
# [loading saved data] 75/496 Category: Cloud Architecture
# [loading saved data] 76/496 Category: Cloud Architecture Design
# [loading saved data] 77/496 Category: Cloud Automation
# [loading saved data] 78/496 Category: Cloud Collaboration
# [loading saved data] 79/496 Category: Cloud Computing
# [loading saved data] 80/496 Category: Cloud Consulting
# [loading saved data] 81/496 Category: Cloud Cost Management
# [loading saved data] 82/496 Category: Cloud Cost Optimization
# [loading saved data] 83/496 Category: Cloud Governance
# [loading saved data] 84/496 Category: Cloud Innovation
# [loading saved data] 85/496 Category: Cloud Management
# [loading saved data] 86/496 Category: Cloud Migration
# [loading saved data] 87/496 Category: Cloud Monitoring
# [loading saved data] 88/496 Category: Cloud Networking
# [loading saved data] 89/496 Category: Cloud Operations
# [loading saved data] 90/496 Category: Cloud Optimization
# [loading saved data] 91/496 Category: Cloud Research & Development
# [loading saved data] 92/496 Category: Cloud Sales
# [loading saved data] 93/496 Category: Cloud Security
# [loading saved data] 94/496 Category: Cloud Storage
# [loading saved data] 95/496 Category: Cloud Training
# [loading saved data] 96/496 Category: Code Development
# [loading saved data] 97/496 Category: Code Review
# [loading saved data] 98/496 Category: Code Writing
# [loading saved data] 99/496 Category: Collaboration
# [loading saved data] 100/496 Category: Collaboration & Communication
# [loading saved data] 101/496 Category: Collection Management
# [loading saved data] 102/496 Category: Collections Management
# [loading saved data] 103/496 Category: Communication & Collaboration
# [loading saved data] 104/496 Category: Community Relations
# [loading saved data] 105/496 Category: Compliance
# [loading saved data] 106/496 Category: Computer Aided Design (CAD)
# [loading saved data] 107/496 Category: Computer Science
# [loading saved data] 108/496 Category: Computer Vision
# [loading saved data] 109/496 Category: Conservation Biology
# [loading saved data] 110/496 Category: Conservation Genetics
# [loading saved data] 111/496 Category: Construction
# [loading saved data] 112/496 Category: Construction & Trades
# [loading saved data] 113/496 Category: Consulting
# [loading saved data] 114/496 Category: Containers
# [loading saved data] 115/496 Category: Content Analysis
# [loading saved data] 116/496 Category: Content Creation
# [loading saved data] 117/496 Category: Content Creation Tools
# [loading saved data] 118/496 Category: Content Distribution
# [loading saved data] 119/496 Category: Content Editing
# [loading saved data] 120/496 Category: Content Management
# [loading saved data] 121/496 Category: Content Marketing
# [loading saved data] 122/496 Category: Content Strategy
# [loading saved data] 123/496 Category: Continuous Delivery
# [loading saved data] 124/496 Category: Contract Management
# [loading saved data] 125/496 Category: Corporate Social Responsibility
# [loading saved data] 126/496 Category: Cost Optimization
# [loading saved data] 127/496 Category: Court Filings
# [loading saved data] 128/496 Category: Court Proceedings
# [loading saved data] 129/496 Category: Creative Work
# [loading saved data] 130/496 Category: Crisis Communication
# [loading saved data] 131/496 Category: Crypto
# [loading saved data] 132/496 Category: Cryptography
# [loading saved data] 133/496 Category: Customer Relationship Management
# [loading saved data] 134/496 Category: Customer Relationship Management (CRM)
# [loading saved data] 135/496 Category: Customer Service
# [loading saved data] 136/496 Category: Cybersecurity
# [loading saved data] 137/496 Category: Dance
# [loading saved data] 138/496 Category: Data Analysis
# [loading saved data] 139/496 Category: Data Center Management
# [loading saved data] 140/496 Category: Data Communication
# [loading saved data] 141/496 Category: Data Engineering
# [loading saved data] 142/496 Category: Data Entry
# [loading saved data] 143/496 Category: Data Ethics
# [loading saved data] 144/496 Category: Data Governance
# [loading saved data] 145/496 Category: Data Management
# [loading saved data] 146/496 Category: Data Mining
# [loading saved data] 147/496 Category: Data Quality
# [loading saved data] 148/496 Category: Data Science
# [loading saved data] 149/496 Category: Data Science Tools
# [loading saved data] 150/496 Category: Data Visualization
# [loading saved data] 151/496 Category: Data Wrangling
# [loading saved data] 152/496 Category: Database Administration
# [loading saved data] 153/496 Category: Deep Learning
# [loading saved data] 154/496 Category: Deployment
# [loading saved data] 155/496 Category: Deployment and Automation
# [loading saved data] 156/496 Category: Design
# [loading saved data] 157/496 Category: Design & Graphics
# [loading saved data] 158/496 Category: Development
# [loading saved data] 159/496 Category: DevOps
# [loading saved data] 160/496 Category: Differential Equations
# [loading saved data] 161/496 Category: Digital Marketing
# [loading saved data] 162/496 Category: Digital Public Relations
# [loading saved data] 163/496 Category: Digitization
# [loading saved data] 164/496 Category: Discrete Mathematics
# [loading saved data] 165/496 Category: Diversity, Equity, and Inclusion (DEI)
# [loading saved data] 166/496 Category: Document Management
# [loading saved data] 167/496 Category: Documentation
# [loading saved data] 168/496 Category: E-commerce
# [loading saved data] 169/496 Category: E-Discovery
# [loading saved data] 170/496 Category: E-filing
# [loading saved data] 171/496 Category: Education & Research
# [loading saved data] 172/496 Category: Education & Training
# [loading saved data] 173/496 Category: Education and Training
# [loading saved data] 174/496 Category: Electronic Health Records (EHR)
# [loading saved data] 175/496 Category: Email
# [loading saved data] 176/496 Category: Email Management
# [loading saved data] 177/496 Category: Embedded Systems
# [loading saved data] 178/496 Category: Engineering
# [loading saved data] 179/496 Category: Engineering & Design
# [loading saved data] 180/496 Category: Entertainment
# [loading saved data] 181/496 Category: Entertainment & Media
# [loading saved data] 182/496 Category: Environmental
# [loading saved data] 183/496 Category: Environmental Advocacy
# [loading saved data] 184/496 Category: Environmental Compliance
# [loading saved data] 185/496 Category: Environmental Education & Outreach
# [loading saved data] 186/496 Category: Environmental Ethics
# [loading saved data] 187/496 Category: Environmental Health
# [loading saved data] 188/496 Category: Environmental Modeling
# [loading saved data] 189/496 Category: Environmental Permits
# [loading saved data] 190/496 Category: Environmental Policy
# [loading saved data] 191/496 Category: Environmental Policy & Regulation
# [loading saved data] 192/496 Category: Environmental Research
# [loading saved data] 193/496 Category: Environmental Science
# [loading saved data] 194/496 Category: Environmental Sustainability
# [loading saved data] 195/496 Category: Ethics
# [loading saved data] 196/496 Category: Ethnobotany
# [loading saved data] 197/496 Category: Event Planning
# [loading saved data] 198/496 Category: Events & Conferences
# [loading saved data] 199/496 Category: Evolutionary Biology
# [loading saved data] 200/496 Category: Exhibition Development
# [loading saved data] 201/496 Category: Fashion Design Software
# [loading saved data] 202/496 Category: Field Service
# [loading saved data] 203/496 Category: File Management
# [loading saved data] 204/496 Category: Finance & Budgeting
# [loading saved data] 205/496 Category: Finance & Legal
# [loading saved data] 206/496 Category: Financial
# [loading saved data] 207/496 Category: Financial Management
# [loading saved data] 208/496 Category: Financial Technology (FinTech)
# [loading saved data] 209/496 Category: FinTech
# [loading saved data] 210/496 Category: Food & Beverages
# [loading saved data] 211/496 Category: Forensic Genetics
# [loading saved data] 212/496 Category: Forensics
# [loading saved data] 213/496 Category: Forest Conservation & Restoration
# [loading saved data] 214/496 Category: Forest Inventory & Monitoring
# [loading saved data] 215/496 Category: Forest Management Planning
# [loading saved data] 216/496 Category: Forestry Operations
# [loading saved data] 217/496 Category: Front-End Frameworks
# [loading saved data] 218/496 Category: Front-End Libraries
# [loading saved data] 219/496 Category: Game Design & Development
# [loading saved data] 220/496 Category: Game Theory
# [loading saved data] 221/496 Category: Gaming
# [loading saved data] 222/496 Category: Gene Editing
# [loading saved data] 223/496 Category: Genetic Counseling
# [loading saved data] 224/496 Category: Genetic Engineering
# [loading saved data] 225/496 Category: Genomics
# [loading saved data] 226/496 Category: Geometry
# [loading saved data] 227/496 Category: GIS & Mapping
# [loading saved data] 228/496 Category: Governance
# [loading saved data] 229/496 Category: Government & Politics
# [loading saved data] 230/496 Category: Graphic Design
# [loading saved data] 231/496 Category: Hardware
# [loading saved data] 232/496 Category: Hardware Management
# [loading saved data] 233/496 Category: Health & Fitness
# [loading saved data] 234/496 Category: Health & Wellness
# [loading saved data] 235/496 Category: Health & Wellness Apps
# [loading saved data] 236/496 Category: Health and Fitness
# [loading saved data] 237/496 Category: Health and Wellness
# [loading saved data] 238/496 Category: Healthcare
# [loading saved data] 239/496 Category: Healthcare Administration
# [loading saved data] 240/496 Category: Home Automation
# [loading saved data] 241/496 Category: Horticulture
# [loading saved data] 242/496 Category: HR
# [loading saved data] 243/496 Category: HR Software
# [loading saved data] 244/496 Category: Human Resources
# [loading saved data] 245/496 Category: Incident Response
# [loading saved data] 246/496 Category: Infrastructure
# [loading saved data] 247/496 Category: Infrastructure Management
# [loading saved data] 248/496 Category: Installation
# [loading saved data] 249/496 Category: Internal Communication
# [loading saved data] 250/496 Category: Internet Browsing
# [loading saved data] 251/496 Category: Internet of Things (IoT)
# 252/496 Category: Inventory Management
# Start time: 2024-06-02 01:11:52.325193
# End time: 2024-06-02 01:11:55.176726
# Gemini API request duration: 0:00:02.851533
# Saving file
# [loading saved data] 253/496 Category: Investor Relations
# 254/496 Category: IoT
# Start time: 2024-06-02 01:11:57.189826
# End time: 2024-06-02 01:11:58.241532
# Gemini API request duration: 0:00:01.051706
# Saving file
# [loading saved data] 255/496 Category: IT & Technology
# [loading saved data] 256/496 Category: IT Support
# [loading saved data] 257/496 Category: Lab Management
# [loading saved data] 258/496 Category: Lab-Specific
# [loading saved data] 259/496 Category: Language & Communication
# [loading saved data] 260/496 Category: Law Enforcement
# [loading saved data] 261/496 Category: Lead Generation
# [loading saved data] 262/496 Category: Leadership
# [loading saved data] 263/496 Category: Learning
# [loading saved data] 264/496 Category: Legal
# [loading saved data] 265/496 Category: Legal & Compliance
# [loading saved data] 266/496 Category: Legal & Regulatory
# [loading saved data] 267/496 Category: Legal Drafting
# [loading saved data] 268/496 Category: Legal Research
# [loading saved data] 269/496 Category: Legal Technology
# 270/496 Category: Legal Writing
# Start time: 2024-06-02 01:12:00.270055
# End time: 2024-06-02 01:12:01.433392
# Gemini API request duration: 0:00:01.163337
# Saving file
# 271/496 Category: Linear Algebra
# Start time: 2024-06-02 01:12:03.441467
# End time: 2024-06-02 01:12:04.384112
# Gemini API request duration: 0:00:00.942645
# Saving file
# 272/496 Category: Literature Review
# Start time: 2024-06-02 01:12:06.393727
# End time: 2024-06-02 01:12:07.354779
# Gemini API request duration: 0:00:00.961052
# Saving file
# 273/496 Category: Machine Learning
# Start time: 2024-06-02 01:12:09.359842
# End time: 2024-06-02 01:12:10.655306
# Gemini API request duration: 0:00:01.295464
# Saving file
# 274/496 Category: Maintenance
# Start time: 2024-06-02 01:12:12.665059
# End time: 2024-06-02 01:12:14.523024
# Gemini API request duration: 0:00:01.857965
# Saving file
# 275/496 Category: Maintenance & Repair
# Start time: 2024-06-02 01:12:16.536110
# End time: 2024-06-02 01:12:23.529645
# Gemini API request duration: 0:00:06.993535
# Saving file
# 276/496 Category: Management
# Start time: 2024-06-02 01:12:25.538049
# End time: 2024-06-02 01:12:26.709239
# Gemini API request duration: 0:00:01.171190
# Saving file
# 277/496 Category: Market Research
# Start time: 2024-06-02 01:12:28.719739
# End time: 2024-06-02 01:12:29.693882
# Gemini API request duration: 0:00:00.974143
# Saving file
# 278/496 Category: Marketing
# Start time: 2024-06-02 01:12:31.708746
# End time: 2024-06-02 01:12:46.588844
# Gemini API request duration: 0:00:14.880098
# Saving file
# 279/496 Category: Marketing & Sales
# Start time: 2024-06-02 01:12:48.598257
# End time: 2024-06-02 01:12:49.645803
# Gemini API request duration: 0:00:01.047546
# Saving file
# [loading saved data] 280/496 Category: Mathematical Biology
# [loading saved data] 281/496 Category: Mathematical Logic
# 282/496 Category: Mathematical Modeling
# Start time: 2024-06-02 01:12:51.654555
# End time: 2024-06-02 01:12:53.024823
# Gemini API request duration: 0:00:01.370268
# Saving file
# 283/496 Category: Mathematical Physics
# Start time: 2024-06-02 01:12:55.028575
# End time: 2024-06-02 01:12:55.896688
# Gemini API request duration: 0:00:00.868113
# Saving file
# 284/496 Category: Meal Planning
# Start time: 2024-06-02 01:12:57.906844
# End time: 2024-06-02 01:12:58.888344
# Gemini API request duration: 0:00:00.981500
# Saving file
# [loading saved data] 285/496 Category: Media and Communication
# [loading saved data] 286/496 Category: Media Editing
# [loading saved data] 287/496 Category: Media Monitoring
# [loading saved data] 288/496 Category: Media Relations
# [loading saved data] 289/496 Category: Medical Genetics
# [loading saved data] 290/496 Category: Meeting Management
# [loading saved data] 291/496 Category: Meetings
# [loading saved data] 292/496 Category: Mergers & Acquisitions (M&A)
# [loading saved data] 293/496 Category: Metaverse
# [loading saved data] 294/496 Category: Military Ethics
# [loading saved data] 295/496 Category: Military History
# [loading saved data] 296/496 Category: Military Intelligence
# [loading saved data] 297/496 Category: Military Law
# [loading saved data] 298/496 Category: Military Logistics
# [loading saved data] 299/496 Category: Military Medicine
# [loading saved data] 300/496 Category: Military Operations
# [loading saved data] 301/496 Category: Military Technology
# [loading saved data] 302/496 Category: Military Training
# [loading saved data] 303/496 Category: Mobile Development
# [loading saved data] 304/496 Category: Mobile Device Management
# [loading saved data] 305/496 Category: Mobile Security
# [loading saved data] 306/496 Category: Modeling
# [loading saved data] 307/496 Category: Modeling and Simulation
# [loading saved data] 308/496 Category: Monitoring and Logging
# [loading saved data] 309/496 Category: Music
# [loading saved data] 310/496 Category: Music Composition
# [loading saved data] 311/496 Category: Music Production
# [loading saved data] 312/496 Category: Natural Language Processing
# [loading saved data] 313/496 Category: Navigation
# [loading saved data] 314/496 Category: Negotiation
# [loading saved data] 315/496 Category: Network Administration
# [loading saved data] 316/496 Category: Network Automation
# [loading saved data] 317/496 Category: Network Documentation
# 318/496 Category: Network Monitoring
# Start time: 2024-06-02 01:13:00.927994
# End time: 2024-06-02 01:13:01.868437
# Gemini API request duration: 0:00:00.940443
# Saving file
# 319/496 Category: Network Planning
# Start time: 2024-06-02 01:13:03.877472
# End time: 2024-06-02 01:13:04.736839
# Gemini API request duration: 0:00:00.859367
# Saving file
# [loading saved data] 320/496 Category: Network Security
# [loading saved data] 321/496 Category: Network Virtualization
# 322/496 Category: Networking
# Start time: 2024-06-02 01:13:06.745675
# End time: 2024-06-02 01:13:09.927237
# Gemini API request duration: 0:00:03.181562
# Saving file
# [loading saved data] 323/496 Category: Note-taking
# [loading saved data] 324/496 Category: Number Theory
# [loading saved data] 325/496 Category: Nutrition Assessment
# [loading saved data] 326/496 Category: Nutrition Education
# [loading saved data] 327/496 Category: Nutrition Software
# [loading saved data] 328/496 Category: Nutritional Counseling
# [loading saved data] 329/496 Category: Office & Administration
# [loading saved data] 330/496 Category: Online Courses
# [loading saved data] 331/496 Category: Online Resources
# [loading saved data] 332/496 Category: Operations
# [loading saved data] 333/496 Category: Operations Management
# [loading saved data] 334/496 Category: Operations Research
# [loading saved data] 335/496 Category: Other
# [loading saved data] 336/496 Category: Outreach
# [loading saved data] 337/496 Category: Paleobotany
# [loading saved data] 338/496 Category: Patient Management
# 339/496 Category: Patient Portals
# Start time: 2024-06-02 01:13:11.952933
# End time: 2024-06-02 01:13:12.894756
# Gemini API request duration: 0:00:00.941823
# Saving file
# 340/496 Category: Penetration Testing
# Start time: 2024-06-02 01:13:14.903625
# End time: 2024-06-02 01:13:16.079013
# Gemini API request duration: 0:00:01.175388
# Saving file
# [loading saved data] 341/496 Category: Performance
# 342/496 Category: Performance Management
# Start time: 2024-06-02 01:13:18.089019
# End time: 2024-06-02 01:13:19.270742
# Gemini API request duration: 0:00:01.181723
# Saving file
# [loading saved data] 343/496 Category: Performance Optimization
# [loading saved data] 344/496 Category: Personal Care
# [loading saved data] 345/496 Category: Personal Development
# [loading saved data] 346/496 Category: Personal Productivity
# [loading saved data] 347/496 Category: Pharmacy
# [loading saved data] 348/496 Category: Photography
# [loading saved data] 349/496 Category: Planning
# [loading saved data] 350/496 Category: Plant Breeding
# [loading saved data] 351/496 Category: Plant Ecology
# [loading saved data] 352/496 Category: Plant Genetics
# [loading saved data] 353/496 Category: Plant Pathology
# [loading saved data] 354/496 Category: Plant Physiology
# [loading saved data] 355/496 Category: Population Genetics
# [loading saved data] 356/496 Category: Portfolio
# [loading saved data] 357/496 Category: Post-Production
# [loading saved data] 358/496 Category: Presentation
# [loading saved data] 359/496 Category: Presentations
# [loading saved data] 360/496 Category: Preservation
# [loading saved data] 361/496 Category: Probability and Statistics
# [loading saved data] 362/496 Category: Product Development
# [loading saved data] 363/496 Category: Professional Development
# [loading saved data] 364/496 Category: Programming
# [loading saved data] 365/496 Category: Project Management
# [loading saved data] 366/496 Category: Public Affairs
# [loading saved data] 367/496 Category: Public Programs
# [loading saved data] 368/496 Category: Public Relations
# [loading saved data] 369/496 Category: Public Relations Measurement & Evaluation
# [loading saved data] 370/496 Category: Public Speaking
# [loading saved data] 371/496 Category: QA Testing
# [loading saved data] 372/496 Category: Quality Improvement
# [loading saved data] 373/496 Category: Quantum Computing
# [loading saved data] 374/496 Category: Radiology Informatics
# [loading saved data] 375/496 Category: Real Estate
# [loading saved data] 376/496 Category: Regulation & Policy
# [loading saved data] 377/496 Category: Regulatory Compliance
# [loading saved data] 378/496 Category: Remote Assistance
# [loading saved data] 379/496 Category: Remote Sensing
# [loading saved data] 380/496 Category: Rendering
# [loading saved data] 381/496 Category: Report Writing
# [loading saved data] 382/496 Category: Reporting
# [loading saved data] 383/496 Category: Reputation Management
# [loading saved data] 384/496 Category: Research
# [loading saved data] 385/496 Category: Research & Analysis
# [loading saved data] 386/496 Category: Research & Development
# [loading saved data] 387/496 Category: Research & Information
# [loading saved data] 388/496 Category: Research & Learning
# [loading saved data] 389/496 Category: Research Ethics
# [loading saved data] 390/496 Category: Rigging
# [loading saved data] 391/496 Category: Risk Management
# [loading saved data] 392/496 Category: Robotics
# [loading saved data] 393/496 Category: Safety
# [loading saved data] 394/496 Category: Sales
# [loading saved data] 395/496 Category: Sales & CRM
# [loading saved data] 396/496 Category: Sales Analytics
# [loading saved data] 397/496 Category: Sales Automation
# [loading saved data] 398/496 Category: Sales Coaching
# [loading saved data] 399/496 Category: Sales Enablement
# [loading saved data] 400/496 Category: Sales Forecasting
# [loading saved data] 401/496 Category: Sales Leadership
# [loading saved data] 402/496 Category: Sales Management
# [loading saved data] 403/496 Category: Sales Strategy
# [loading saved data] 404/496 Category: Sales Training
# [loading saved data] 405/496 Category: Scheduling
# [loading saved data] 406/496 Category: Scientific Collaboration
# [loading saved data] 407/496 Category: Scientific Communication
# [loading saved data] 408/496 Category: Scientific Computing
# [loading saved data] 409/496 Category: Scientific Data Visualization
# [loading saved data] 410/496 Category: Scientific Ethics
# [loading saved data] 411/496 Category: Scientific Instruments
# [loading saved data] 412/496 Category: Scientific Outreach
# [loading saved data] 413/496 Category: Scientific Research
# [loading saved data] 414/496 Category: Scientific Software
# [loading saved data] 415/496 Category: Scientific Software Development
# [loading saved data] 416/496 Category: Scientific Writing
# [loading saved data] 417/496 Category: Security
# [loading saved data] 418/496 Category: Security & Compliance
# [loading saved data] 419/496 Category: Security & Privacy
# [loading saved data] 420/496 Category: Security Automation
# [loading saved data] 421/496 Category: Security Awareness
# [loading saved data] 422/496 Category: Security Engineering
# [loading saved data] 423/496 Category: Security Monitoring
# [loading saved data] 424/496 Category: SEO
# [loading saved data] 425/496 Category: Sequence Alignment
# [loading saved data] 426/496 Category: Server Management
# [loading saved data] 427/496 Category: Serverless Computing
# [loading saved data] 428/496 Category: Set Theory
# [loading saved data] 429/496 Category: Shopping
# [loading saved data] 430/496 Category: Shopping & Retail
# [loading saved data] 431/496 Category: Social Media
# [loading saved data] 432/496 Category: Software
# [loading saved data] 433/496 Category: Software & Apps
# [loading saved data] 434/496 Category: Software & Tools
# [loading saved data] 435/496 Category: Software Development
# [loading saved data] 436/496 Category: Software Management
# [loading saved data] 437/496 Category: Software Testing
# [loading saved data] 438/496 Category: Software Use
# [loading saved data] 439/496 Category: Sports & Recreation
# [loading saved data] 440/496 Category: Spreadsheet
# [loading saved data] 441/496 Category: Strategic Partnerships
# [loading saved data] 442/496 Category: Strategy
# [loading saved data] 443/496 Category: Strategy & Planning
# [loading saved data] 444/496 Category: Structural Engineering
# [loading saved data] 445/496 Category: Supply Chain
# [loading saved data] 446/496 Category: Supply Chain Management
# [loading saved data] 447/496 Category: Sustainability
# [loading saved data] 448/496 Category: System Administration
# [loading saved data] 449/496 Category: System Settings
# [loading saved data] 450/496 Category: Tax Planning
# [loading saved data] 451/496 Category: Tax Preparation
# [loading saved data] 452/496 Category: Teaching
# [loading saved data] 453/496 Category: Technical
# [loading saved data] 454/496 Category: Technical Support
# [loading saved data] 455/496 Category: Technology
# [loading saved data] 456/496 Category: Technology & IT
# [loading saved data] 457/496 Category: Technology & Tools
# [loading saved data] 458/496 Category: Technology and Software
# [loading saved data] 459/496 Category: Telemedicine
# [loading saved data] 460/496 Category: Testing
# [loading saved data] 461/496 Category: Texturing
# [loading saved data] 462/496 Category: Threat Intelligence
# [loading saved data] 463/496 Category: Time Management
# [loading saved data] 464/496 Category: Tools & Utilities
# [loading saved data] 465/496 Category: Topology
# [loading saved data] 466/496 Category: Training
# [loading saved data] 467/496 Category: Transcriptomics
# [loading saved data] 468/496 Category: Transportation & Logistics
# [loading saved data] 469/496 Category: Travel & Booking
# 470/496 Category: Travel and Booking
# Start time: 2024-06-02 01:13:21.355403
# End time: 2024-06-02 01:13:26.822665
# Gemini API request duration: 0:00:05.467262
# Saving file
# [loading saved data] 471/496 Category: Trial Preparation
# [loading saved data] 472/496 Category: Trial Proceedings
# [loading saved data] 473/496 Category: Trigonometry
# [loading saved data] 474/496 Category: Troubleshooting
# [loading saved data] 475/496 Category: Troubleshooting & Problem Solving
# [loading saved data] 476/496 Category: User Experience (UX)
# [loading saved data] 477/496 Category: User Interface (UI)
# [loading saved data] 478/496 Category: Vendor Management
# [loading saved data] 479/496 Category: Video Conferencing
# [loading saved data] 480/496 Category: Video Editing
# [loading saved data] 481/496 Category: Video Games
# [loading saved data] 482/496 Category: Virtual Reality
# [loading saved data] 483/496 Category: Virtual Reality (VR)
# [loading saved data] 484/496 Category: Virtual Reality (VR) & Augmented Reality (AR)
# [loading saved data] 485/496 Category: Virtualization
# [loading saved data] 486/496 Category: Visualization
# [loading saved data] 487/496 Category: Vulnerability Management
# [loading saved data] 488/496 Category: Weather
# [loading saved data] 489/496 Category: Web Design
# [loading saved data] 490/496 Category: Web Development
# [loading saved data] 491/496 Category: Web Performance
# [loading saved data] 492/496 Category: Web Security
# [loading saved data] 493/496 Category: Wildlife Management
# [loading saved data] 494/496 Category: Wireless Networking
# [loading saved data] 495/496 Category: Word Processing
# [loading saved data] 496/496 Category: Writing
